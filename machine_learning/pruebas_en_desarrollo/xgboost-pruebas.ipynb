# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ## Pruebas para modelo 001 conversion (Todos los features)

# %%
train = pd.read_pickle("../../../modelo/armado_datos/train_completo_installs.pkl")

# %%
cantidad_columnas = len(train.columns) - 1

# %%
cantidad_columnas
# Out:
# 103

# %%
train["cantidad_nans"] = train.isnull().sum(axis=1)

# %%
train["cantidad_nans"].max()
# Out:
# 103

# %%
train["cantidad_nans"].value_counts().head()
# Out:
# 103    312769
# 79     191777
# 57     172744
# 33     162182
# 54      86376
# Name: cantidad_nans, dtype: int64

# %%
train_reducido = train[train["cantidad_nans"] < 103]

# %%
len(train_reducido)
# Out:
# 737575

# %%
X, y = train_reducido.drop("target",axis = 1), train_reducido["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

# %%
len(y_test)
# Out:
# 147515

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)

#La mejor
# Datos sacando las filas que tienen todos los nans
#[86]	train-rmse:46194.3	test-rmse:46568
# len 700 mil



# Datos completos con nans
#[94]	train-rmse:56717.6	test-rmse:57109.4

#Datos completos con 0
#[79]	train-rmse:56752.8	test-rmse:57114.2

# Pareciera que funciona mejor con nans
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:209110	test-rmse:209337
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:189260	test-rmse:189517
# [2]	train-rmse:171552	test-rmse:171780
# [3]	train-rmse:155729	test-rmse:155926
# [4]	train-rmse:141620	test-rmse:141814
# [5]	train-rmse:129057	test-rmse:129253
# [6]	train-rmse:117916	test-rmse:118093
# [7]	train-rmse:108042	test-rmse:108218
# [8]	train-rmse:99320.3	test-rmse:99498.7
# [9]	train-rmse:91660.1	test-rmse:91833.2
# [10]	train-rmse:84950.8	test-rmse:85111.3
# [11]	train-rmse:79090	test-rmse:79260.6
# [12]	train-rmse:74015.4	test-rmse:74178.7
# [13]	train-rmse:69617.1	test-rmse:69787.1
# [14]	train-rmse:65852.6	test-rmse:66013.8
# [15]	train-rmse:62623.6	test-rmse:62791.6
# [16]	train-rmse:59887.6	test-rmse:60054.6
# [17]	train-rmse:57572.3	test-rmse:57744.5
# [18]	train-rmse:55630	test-rmse:55801
# [19]	train-rmse:54005	test-rmse:54176.4
# [20]	train-rmse:52646.2	test-rmse:52824.4
# [21]	train-rmse:51518.3	test-rmse:51701.2
# [22]	train-rmse:50584.7	test-rmse:50769
# [23]	train-rmse:49821.7	test-rmse:50004.1
# [24]	train-rmse:49184	test-rmse:49373.2
# [25]	train-rmse:48664.5	test-rmse:48859.4
# [26]	train-rmse:48242.9	test-rmse:48436.9
# [27]	train-rmse:47894.4	test-rmse:48090.5
# [28]	train-rmse:47611.9	test-rmse:47808
# [29]	train-rmse:47377.4	test-rmse:47578.3
# [30]	train-rmse:47184.4	test-rmse:47388.4
# [31]	train-rmse:47030.2	test-rmse:47236.4
# [32]	train-rmse:46903.7	test-rmse:47112.3
# [33]	train-rmse:46799.7	test-rmse:47011.9
# [34]	train-rmse:46712	test-rmse:46928.6
# [35]	train-rmse:46643	test-rmse:46862.2
# [36]	train-rmse:46586.3	test-rmse:46807.4
# [37]	train-rmse:46536.9	test-rmse:46763.9
# [38]	train-rmse:46496.5	test-rmse:46727.5
# [39]	train-rmse:46466.4	test-rmse:46699.1
# [40]	train-rmse:46441	test-rmse:46674.3
# [41]	train-rmse:46416.1	test-rmse:46656.9
# [42]	train-rmse:46397.4	test-rmse:46640.5
# [43]	train-rmse:46382.8	test-rmse:46627
# [44]	train-rmse:46365.2	test-rmse:46616.6
# [45]	train-rmse:46352.5	test-rmse:46608.9
# [46]	train-rmse:46343.9	test-rmse:46601.9
# [47]	train-rmse:46333.4	test-rmse:46595.7
# [48]	train-rmse:46326	test-rmse:46591.5
# [49]	train-rmse:46317	test-rmse:46587.9
# [50]	train-rmse:46308.4	test-rmse:46585.1
# [51]	train-rmse:46303	test-rmse:46583.6
# [52]	train-rmse:46296	test-rmse:46581.1
# [53]	train-rmse:46291.4	test-rmse:46579.2
# [54]	train-rmse:46285.8	test-rmse:46577.8
# [55]	train-rmse:46281.2	test-rmse:46577.1
# [56]	train-rmse:46273.6	test-rmse:46575.2
# [57]	train-rmse:46268.2	test-rmse:46574.7
# [58]	train-rmse:46264.4	test-rmse:46573
# [59]	train-rmse:46263	test-rmse:46572.8
# [60]	train-rmse:46257.8	test-rmse:46572.2
# [61]	train-rmse:46254.6	test-rmse:46572.1
# [62]	train-rmse:46250	test-rmse:46572
# [63]	train-rmse:46249.3	test-rmse:46572
# [64]	train-rmse:46248	test-rmse:46572.3
# [65]	train-rmse:46243	test-rmse:46571.4
# [66]	train-rmse:46242	test-rmse:46571.4
# [67]	train-rmse:46240.1	test-rmse:46570.7
# [68]	train-rmse:46239	test-rmse:46570.7
# [69]	train-rmse:46234.5	test-rmse:46571
# [70]	train-rmse:46230.1	test-rmse:46570
# [71]	train-rmse:46229.5	test-rmse:46570.1
# [72]	train-rmse:46228.5	test-rmse:46570.2
# [73]	train-rmse:46226.4	test-rmse:46570
# [74]	train-rmse:46220.5	test-rmse:46569.2
# [75]	train-rmse:46219.5	test-rmse:46569.4
# [76]	train-rmse:46215.3	test-rmse:46569.8
# [77]	train-rmse:46212.3	test-rmse:46569.4
# [78]	train-rmse:46210.4	test-rmse:46569.3
# [79]	train-rmse:46206.6	test-rmse:46568.1
# [80]	train-rmse:46204.6	test-rmse:46568.1
# [81]	train-rmse:46203.1	test-rmse:46568.1
# [82]	train-rmse:46201.5	test-rmse:46568.2
# [83]	train-rmse:46199.9	test-rmse:46568.2
# [84]	train-rmse:46198.9	test-rmse:46568.4
# [85]	train-rmse:46197	test-rmse:46568.8
# [86]	train-rmse:46194.3	test-rmse:46568
# [87]	train-rmse:46192.8	test-rmse:46568.1
# [88]	train-rmse:46190.8	test-rmse:46568.3
# [89]	train-rmse:46189.5	test-rmse:46568.8
# [90]	train-rmse:46187.5	test-rmse:46568.9
# [91]	train-rmse:46184.5	test-rmse:46569.4
# [92]	train-rmse:46180.6	test-rmse:46569.1
# [93]	train-rmse:46177.4	test-rmse:46569.5
# [94]	train-rmse:46175.3	test-rmse:46568.9
# [95]	train-rmse:46172.7	test-rmse:46569.3
# [96]	train-rmse:46169.1	test-rmse:46569.2
# [97]	train-rmse:46166	test-rmse:46569.5
# [98]	train-rmse:46165.1	test-rmse:46569.4
# [99]	train-rmse:46163.9	test-rmse:46569.5
# [100]	train-rmse:46163	test-rmse:46570.2
# [101]	train-rmse:46158.8	test-rmse:46570
# [102]	train-rmse:46157.3	test-rmse:46570.3
# [103]	train-rmse:46155.4	test-rmse:46570.8
# [104]	train-rmse:46151.7	test-rmse:46570.1
# [105]	train-rmse:46149.3	test-rmse:46571
# [106]	train-rmse:46148.4	test-rmse:46571.7
# Stopping. Best iteration:
# [86]	train-rmse:46194.3	test-rmse:46568

# %% [markdown]
# ---

# %% [markdown]
# ## Pruebas para auctions modelo 001 (Todos los features)

# %%
train = pd.read_pickle("../../armado_datos/train_completo_auctions.pkl")

# %%
train["cant_nulos"] = train.isnull().sum(axis = 1)

# %%
cantidad_columnas
# Out:
# 103

# %%
train["cant_nulos"].max()
# Out:
# 57

# %%
len(train)
# Out:
# 1286041

# %%
train["cant_nulos"].value_counts().head(10)
# Out:
# 57    858003
# 33    162182
# 36    143610
# 54     86376
# 24     14708
# 27      6924
# 3       6341
# 6       3538
# 0       3250
# 21      1109
# Name: cant_nulos, dtype: int64

# %%
len(train[train["cant_nulos"] < 90])

# %%
train_disminuido = train[train["cant_nulos"] < 90]

# %% [markdown]
# ## Porcentaje de valores maximos dentro de lo disminuido

# %%
len(train_disminuido[train_disminuido["target"] == train["target"].max()]) / len(train_disminuido) * 100
# Out:
# 23.41790418092402

# %%
X, y = train.drop("target",axis = 1), train["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

# %%
len(y_test)
# Out:
# 257209

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)

# Datos completos
#[516]	train-rmse:87216.3	test-rmse:88728.8

#Filtrado menor a 93 nulos
#len = 1151517
#[723]	train-rmse:85781.6	test-rmse:87736.8
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:148650	test-rmse:148597
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:139418	test-rmse:139382
# [2]	train-rmse:131465	test-rmse:131453
# [3]	train-rmse:124609	test-rmse:124636
# [4]	train-rmse:118807	test-rmse:118844
# [5]	train-rmse:113844	test-rmse:113909
# [6]	train-rmse:109660	test-rmse:109751
# [7]	train-rmse:106127	test-rmse:106243
# [8]	train-rmse:103177	test-rmse:103310
# [9]	train-rmse:100709	test-rmse:100858
# [10]	train-rmse:98658.9	test-rmse:98828.1
# [11]	train-rmse:96954.5	test-rmse:97137.9
# [12]	train-rmse:95544.5	test-rmse:95743.5
# [13]	train-rmse:94381.2	test-rmse:94591
# [14]	train-rmse:93428.8	test-rmse:93649.1
# [15]	train-rmse:92635.1	test-rmse:92867.2
# [16]	train-rmse:91977.9	test-rmse:92222.8
# [17]	train-rmse:91436.4	test-rmse:91690.7
# [18]	train-rmse:90990.6	test-rmse:91254.8
# [19]	train-rmse:90627.8	test-rmse:90896.9
# [20]	train-rmse:90323.6	test-rmse:90602.6
# [21]	train-rmse:90076.1	test-rmse:90359.9
# [22]	train-rmse:89859.4	test-rmse:90151.4
# [23]	train-rmse:89692.6	test-rmse:89989.9
# [24]	train-rmse:89548.4	test-rmse:89853.6
# [25]	train-rmse:89428.8	test-rmse:89740.3
# [26]	train-rmse:89329.5	test-rmse:89645.9
# [27]	train-rmse:89249	test-rmse:89567
# [28]	train-rmse:89175.9	test-rmse:89501
# [29]	train-rmse:89109.3	test-rmse:89439.4
# [30]	train-rmse:89056.9	test-rmse:89391.1
# [31]	train-rmse:89012.2	test-rmse:89352.3
# [32]	train-rmse:88973.1	test-rmse:89316.1
# [33]	train-rmse:88938.9	test-rmse:89287.4
# [34]	train-rmse:88909.5	test-rmse:89262.4
# [35]	train-rmse:88885	test-rmse:89241.2
# [36]	train-rmse:88860.3	test-rmse:89222.5
# [37]	train-rmse:88839.5	test-rmse:89206
# [38]	train-rmse:88815.9	test-rmse:89187.4
# [39]	train-rmse:88795.5	test-rmse:89171.3
# [40]	train-rmse:88779.5	test-rmse:89159.3
# [41]	train-rmse:88764.4	test-rmse:89148.6
# [42]	train-rmse:88742.2	test-rmse:89129.8
# [43]	train-rmse:88728.9	test-rmse:89120.2
# [44]	train-rmse:88717.4	test-rmse:89110.6
# [45]	train-rmse:88705.2	test-rmse:89101.5
# [46]	train-rmse:88687.4	test-rmse:89085.5
# [47]	train-rmse:88675.6	test-rmse:89078.8
# [48]	train-rmse:88665.5	test-rmse:89071.9
# [49]	train-rmse:88655.3	test-rmse:89065.3
# [50]	train-rmse:88643.9	test-rmse:89058.7
# [51]	train-rmse:88634.7	test-rmse:89052.9
# [52]	train-rmse:88624.3	test-rmse:89047.1
# [53]	train-rmse:88616.8	test-rmse:89042.5
# [54]	train-rmse:88603.5	test-rmse:89032.7
# [55]	train-rmse:88595	test-rmse:89027.8
# [56]	train-rmse:88581.7	test-rmse:89017.5
# [57]	train-rmse:88572.8	test-rmse:89013.1
# [58]	train-rmse:88561.7	test-rmse:89005.2
# [59]	train-rmse:88553.2	test-rmse:89000.1
# [60]	train-rmse:88544.5	test-rmse:88995
# [61]	train-rmse:88537	test-rmse:88991.5
# [62]	train-rmse:88530.5	test-rmse:88988.3
# [63]	train-rmse:88522.9	test-rmse:88983.5
# [64]	train-rmse:88516.9	test-rmse:88980.4
# [65]	train-rmse:88507.8	test-rmse:88973.1
# [66]	train-rmse:88501.7	test-rmse:88969.9
# [67]	train-rmse:88494.2	test-rmse:88965.5
# [68]	train-rmse:88487.5	test-rmse:88961.8
# [69]	train-rmse:88479.6	test-rmse:88957.3
# [70]	train-rmse:88473.5	test-rmse:88955.8
# [71]	train-rmse:88466.8	test-rmse:88952.3
# [72]	train-rmse:88462.6	test-rmse:88950.5
# [73]	train-rmse:88456.5	test-rmse:88947.1
# [74]	train-rmse:88451	test-rmse:88944
# [75]	train-rmse:88446.8	test-rmse:88942.7
# [76]	train-rmse:88440.3	test-rmse:88941.4
# [77]	train-rmse:88435.3	test-rmse:88939
# [78]	train-rmse:88431.7	test-rmse:88936.5
# [79]	train-rmse:88426.1	test-rmse:88934
# [80]	train-rmse:88422.1	test-rmse:88934
# [81]	train-rmse:88415.7	test-rmse:88929.8
# [82]	train-rmse:88410.3	test-rmse:88927.3
# [83]	train-rmse:88405.6	test-rmse:88926.1
# [84]	train-rmse:88400	test-rmse:88923.9
# [85]	train-rmse:88394.2	test-rmse:88921.8
# [86]	train-rmse:88390.6	test-rmse:88920.5
# [87]	train-rmse:88385	test-rmse:88918.3
# [88]	train-rmse:88379.1	test-rmse:88915.5
# [89]	train-rmse:88373	test-rmse:88912.5
# [90]	train-rmse:88368.2	test-rmse:88910.5
# [91]	train-rmse:88364.5	test-rmse:88909.7
# [92]	train-rmse:88359.7	test-rmse:88908.2
# [93]	train-rmse:88353.1	test-rmse:88905.3
# [94]	train-rmse:88348.6	test-rmse:88904.1
# [95]	train-rmse:88344.1	test-rmse:88902.3
# [96]	train-rmse:88339.4	test-rmse:88900.4
# [97]	train-rmse:88334.7	test-rmse:88899.2
# [98]	train-rmse:88330.1	test-rmse:88898.6
# [99]	train-rmse:88324.3	test-rmse:88896.5
# [100]	train-rmse:88319.1	test-rmse:88893.7
# [101]	train-rmse:88314.7	test-rmse:88891.8
# [102]	train-rmse:88311.3	test-rmse:88890.3
# [103]	train-rmse:88308.5	test-rmse:88889.2
# [104]	train-rmse:88304.6	test-rmse:88889
# [105]	train-rmse:88302.5	test-rmse:88888.5
# [106]	train-rmse:88299	test-rmse:88887.1
# [107]	train-rmse:88296	test-rmse:88885.8
# [108]	train-rmse:88292.3	test-rmse:88884.6
# [109]	train-rmse:88285.4	test-rmse:88881.2
# [110]	train-rmse:88281.5	test-rmse:88881.3
# [111]	train-rmse:88276.9	test-rmse:88879.4
# [112]	train-rmse:88273.6	test-rmse:88878.4
# [113]	train-rmse:88268.2	test-rmse:88876.8
# [114]	train-rmse:88264.9	test-rmse:88876.5
# [115]	train-rmse:88262.9	test-rmse:88875.9
# [116]	train-rmse:88259.3	test-rmse:88874.7
# [117]	train-rmse:88254.3	test-rmse:88873.7
# [118]	train-rmse:88251.7	test-rmse:88872.5
# [119]	train-rmse:88247.3	test-rmse:88871.1
# [120]	train-rmse:88241.7	test-rmse:88869.6
# [121]	train-rmse:88237.6	test-rmse:88869.3
# [122]	train-rmse:88231.2	test-rmse:88867.2
# [123]	train-rmse:88226.1	test-rmse:88866
# [124]	train-rmse:88221.7	test-rmse:88864.1
# [125]	train-rmse:88219.7	test-rmse:88863.9
# [126]	train-rmse:88214.5	test-rmse:88863.1
# [127]	train-rmse:88210.8	test-rmse:88862.1
# [128]	train-rmse:88204	test-rmse:88860.9
# [129]	train-rmse:88199	test-rmse:88859.2
# [130]	train-rmse:88194	test-rmse:88857.8
# [131]	train-rmse:88190	test-rmse:88857.3
# [132]	train-rmse:88184.8	test-rmse:88855.4
# [133]	train-rmse:88180.9	test-rmse:88854.4
# [134]	train-rmse:88175.3	test-rmse:88852.1
# [135]	train-rmse:88171.7	test-rmse:88851
# [136]	train-rmse:88167.4	test-rmse:88850.5
# [137]	train-rmse:88162.3	test-rmse:88849.1
# [138]	train-rmse:88157.4	test-rmse:88848
# [139]	train-rmse:88151.4	test-rmse:88846.7
# [140]	train-rmse:88147.6	test-rmse:88846.8
# [141]	train-rmse:88143.3	test-rmse:88845.5
# [142]	train-rmse:88139.7	test-rmse:88844.7
# [143]	train-rmse:88134.9	test-rmse:88843.6
# [144]	train-rmse:88130.8	test-rmse:88842.2
# [145]	train-rmse:88125.7	test-rmse:88840.1
# [146]	train-rmse:88122	test-rmse:88839.9
# [147]	train-rmse:88119	test-rmse:88840
# [148]	train-rmse:88113.8	test-rmse:88839.9
# [149]	train-rmse:88113	test-rmse:88839.8
# [150]	train-rmse:88111	test-rmse:88839.6
# [151]	train-rmse:88109.9	test-rmse:88839.8
# [152]	train-rmse:88106.1	test-rmse:88839.1
# [153]	train-rmse:88101.8	test-rmse:88838.2
# [154]	train-rmse:88095.8	test-rmse:88837.1
# [155]	train-rmse:88092.1	test-rmse:88836.2
# [156]	train-rmse:88088.7	test-rmse:88835.7
# [157]	train-rmse:88087.8	test-rmse:88836.2
# [158]	train-rmse:88081.8	test-rmse:88834.7
# [159]	train-rmse:88080.6	test-rmse:88834.4
# [160]	train-rmse:88076	test-rmse:88832.8
# [161]	train-rmse:88070.1	test-rmse:88831.8
# [162]	train-rmse:88068.8	test-rmse:88831.6
# [163]	train-rmse:88066.2	test-rmse:88831.1
# [164]	train-rmse:88065.2	test-rmse:88830.5
# [165]	train-rmse:88062.1	test-rmse:88830.4
# [166]	train-rmse:88057.4	test-rmse:88828.4
# [167]	train-rmse:88053	test-rmse:88827.8
# [168]	train-rmse:88050	test-rmse:88827.5
# [169]	train-rmse:88047.3	test-rmse:88826.5
# [170]	train-rmse:88042.8	test-rmse:88825.4
# [171]	train-rmse:88038.2	test-rmse:88823.7
# [172]	train-rmse:88035.7	test-rmse:88823.1
# [173]	train-rmse:88035.1	test-rmse:88822.9
# [174]	train-rmse:88032.2	test-rmse:88822
# [175]	train-rmse:88031.3	test-rmse:88822
# [176]	train-rmse:88028.6	test-rmse:88821.8
# [177]	train-rmse:88027.5	test-rmse:88821.7
# [178]	train-rmse:88025.2	test-rmse:88821.6
# [179]	train-rmse:88021.8	test-rmse:88821.2
# [180]	train-rmse:88018.5	test-rmse:88821.2
# [181]	train-rmse:88014.1	test-rmse:88820.1
# [182]	train-rmse:88010.9	test-rmse:88820.1
# [183]	train-rmse:88008.7	test-rmse:88819.6
# [184]	train-rmse:88003.7	test-rmse:88818.5
# [185]	train-rmse:88003.1	test-rmse:88818.5
# [186]	train-rmse:88001.5	test-rmse:88818.3
# [187]	train-rmse:87996.5	test-rmse:88817.2
# [188]	train-rmse:87992	test-rmse:88815.6
# [189]	train-rmse:87989.5	test-rmse:88816
# [190]	train-rmse:87984.9	test-rmse:88815
# [191]	train-rmse:87982	test-rmse:88814.3
# [192]	train-rmse:87980.5	test-rmse:88814.5
# [193]	train-rmse:87977.1	test-rmse:88813.6
# [194]	train-rmse:87974.2	test-rmse:88813.5
# [195]	train-rmse:87971.8	test-rmse:88813.1
# [196]	train-rmse:87969	test-rmse:88812.8
# [197]	train-rmse:87967.9	test-rmse:88812.8
# [198]	train-rmse:87963.6	test-rmse:88812.5
# [199]	train-rmse:87961.1	test-rmse:88812.3
# [200]	train-rmse:87957.9	test-rmse:88811.8
# [201]	train-rmse:87955.8	test-rmse:88811.9
# [202]	train-rmse:87953.1	test-rmse:88812
# [203]	train-rmse:87951.2	test-rmse:88811.6
# [204]	train-rmse:87948.5	test-rmse:88811.1
# [205]	train-rmse:87947.9	test-rmse:88811.5
# [206]	train-rmse:87943.5	test-rmse:88810.7
# [207]	train-rmse:87937.4	test-rmse:88808.5
# [208]	train-rmse:87933.9	test-rmse:88808.1
# [209]	train-rmse:87931.5	test-rmse:88807.4
# [210]	train-rmse:87927.7	test-rmse:88806.7
# [211]	train-rmse:87924.1	test-rmse:88805.8
# [212]	train-rmse:87920.4	test-rmse:88804.4
# [213]	train-rmse:87920	test-rmse:88804.8
# [214]	train-rmse:87919.5	test-rmse:88804.5
# [215]	train-rmse:87915.1	test-rmse:88803.5
# [216]	train-rmse:87911.1	test-rmse:88802.3
# [217]	train-rmse:87907.2	test-rmse:88801.9
# [218]	train-rmse:87905.1	test-rmse:88801.6
# [219]	train-rmse:87902.7	test-rmse:88801.6
# [220]	train-rmse:87900.1	test-rmse:88800.7
# [221]	train-rmse:87898	test-rmse:88800.8
# [222]	train-rmse:87894.4	test-rmse:88799.6
# [223]	train-rmse:87892.6	test-rmse:88799.1
# [224]	train-rmse:87891.2	test-rmse:88798.9
# [225]	train-rmse:87890.4	test-rmse:88798.8
# [226]	train-rmse:87886.7	test-rmse:88797.5
# [227]	train-rmse:87882.7	test-rmse:88796.4
# [228]	train-rmse:87876.9	test-rmse:88794.8
# [229]	train-rmse:87874.7	test-rmse:88795.3
# [230]	train-rmse:87872.9	test-rmse:88795.1
# [231]	train-rmse:87872.4	test-rmse:88795.1
# [232]	train-rmse:87870.5	test-rmse:88795
# [233]	train-rmse:87867.6	test-rmse:88794.6
# [234]	train-rmse:87866.4	test-rmse:88794.4
# [235]	train-rmse:87862.7	test-rmse:88793.7
# [236]	train-rmse:87858.2	test-rmse:88790.6
# [237]	train-rmse:87853.7	test-rmse:88790
# [238]	train-rmse:87851.4	test-rmse:88790.2
# [239]	train-rmse:87847.9	test-rmse:88790.2
# [240]	train-rmse:87844.5	test-rmse:88790.1
# [241]	train-rmse:87840.5	test-rmse:88789.6
# [242]	train-rmse:87836	test-rmse:88787.7
# [243]	train-rmse:87833.1	test-rmse:88787.8
# [244]	train-rmse:87830.5	test-rmse:88787.2
# [245]	train-rmse:87826.8	test-rmse:88787
# [246]	train-rmse:87823.3	test-rmse:88786.2
# [247]	train-rmse:87819.7	test-rmse:88786
# [248]	train-rmse:87819.1	test-rmse:88786
# [249]	train-rmse:87818	test-rmse:88785.8
# [250]	train-rmse:87816.9	test-rmse:88786
# [251]	train-rmse:87816	test-rmse:88785.8
# [252]	train-rmse:87815.3	test-rmse:88785.8
# [253]	train-rmse:87814.7	test-rmse:88786.1
# [254]	train-rmse:87813.8	test-rmse:88786.3
# [255]	train-rmse:87811.2	test-rmse:88786.1
# [256]	train-rmse:87809.1	test-rmse:88786.1
# [257]	train-rmse:87805.9	test-rmse:88785.3
# [258]	train-rmse:87803.1	test-rmse:88784.8
# [259]	train-rmse:87802.6	test-rmse:88784.8
# [260]	train-rmse:87799.7	test-rmse:88783.5
# [261]	train-rmse:87799.1	test-rmse:88783.3
# [262]	train-rmse:87798.8	test-rmse:88783.5
# [263]	train-rmse:87795.7	test-rmse:88783.1
# [264]	train-rmse:87793.1	test-rmse:88783.1
# [265]	train-rmse:87790.5	test-rmse:88782.6
# [266]	train-rmse:87787.3	test-rmse:88782.3
# [267]	train-rmse:87783.7	test-rmse:88781.4
# [268]	train-rmse:87778.5	test-rmse:88781.5
# [269]	train-rmse:87774.3	test-rmse:88780.2
# [270]	train-rmse:87770.3	test-rmse:88779.4
# [271]	train-rmse:87768.5	test-rmse:88779
# [272]	train-rmse:87767.8	test-rmse:88779
# [273]	train-rmse:87763.3	test-rmse:88777.5
# [274]	train-rmse:87759.7	test-rmse:88777.4
# [275]	train-rmse:87755.8	test-rmse:88776.4
# [276]	train-rmse:87752.4	test-rmse:88776.8
# [277]	train-rmse:87751.1	test-rmse:88777.1
# [278]	train-rmse:87746.6	test-rmse:88776.7
# [279]	train-rmse:87745.6	test-rmse:88776.6
# [280]	train-rmse:87742.3	test-rmse:88775.2
# [281]	train-rmse:87739.2	test-rmse:88774.7
# [282]	train-rmse:87737.5	test-rmse:88775
# [283]	train-rmse:87734.3	test-rmse:88774
# [284]	train-rmse:87731.5	test-rmse:88774.2
# [285]	train-rmse:87730	test-rmse:88774.4
# [286]	train-rmse:87726.2	test-rmse:88773.5
# [287]	train-rmse:87724.7	test-rmse:88773.7
# [288]	train-rmse:87721.6	test-rmse:88773.2
# [289]	train-rmse:87720.1	test-rmse:88773.3
# [290]	train-rmse:87716.6	test-rmse:88773
# [291]	train-rmse:87713.5	test-rmse:88772.6
# [292]	train-rmse:87709.8	test-rmse:88772.4
# [293]	train-rmse:87707.2	test-rmse:88772.4
# [294]	train-rmse:87703.1	test-rmse:88771.9
# [295]	train-rmse:87699.5	test-rmse:88771.4
# [296]	train-rmse:87698.3	test-rmse:88771.2
# [297]	train-rmse:87696	test-rmse:88771.1
# [298]	train-rmse:87693.2	test-rmse:88770.7
# [299]	train-rmse:87689.8	test-rmse:88770.4
# [300]	train-rmse:87687.4	test-rmse:88769.7
# [301]	train-rmse:87683.9	test-rmse:88769.1
# [302]	train-rmse:87681.6	test-rmse:88768.6
# [303]	train-rmse:87678.8	test-rmse:88768.1
# [304]	train-rmse:87678.1	test-rmse:88768.3
# [305]	train-rmse:87677.3	test-rmse:88768.2
# [306]	train-rmse:87677	test-rmse:88768.4
# [307]	train-rmse:87676.2	test-rmse:88768.5
# [308]	train-rmse:87675.1	test-rmse:88768.1
# [309]	train-rmse:87672.2	test-rmse:88767.9
# [310]	train-rmse:87670.4	test-rmse:88768.6
# [311]	train-rmse:87668.8	test-rmse:88768.6
# [312]	train-rmse:87668.2	test-rmse:88768.6
# [313]	train-rmse:87664.8	test-rmse:88767.3
# [314]	train-rmse:87661.5	test-rmse:88767.3
# [315]	train-rmse:87658.1	test-rmse:88767.1
# [316]	train-rmse:87654.7	test-rmse:88766.3
# [317]	train-rmse:87651.2	test-rmse:88765.1
# [318]	train-rmse:87647.6	test-rmse:88764.6
# [319]	train-rmse:87646.5	test-rmse:88764.5
# [320]	train-rmse:87643.1	test-rmse:88763.8
# [321]	train-rmse:87640.2	test-rmse:88763.8
# [322]	train-rmse:87638.2	test-rmse:88763.6
# [323]	train-rmse:87634.9	test-rmse:88762.8
# [324]	train-rmse:87633.2	test-rmse:88762.6
# [325]	train-rmse:87628.7	test-rmse:88763
# [326]	train-rmse:87625	test-rmse:88762.2
# [327]	train-rmse:87623.7	test-rmse:88762.1
# [328]	train-rmse:87622.2	test-rmse:88762.1
# [329]	train-rmse:87619.9	test-rmse:88761.5
# [330]	train-rmse:87617.6	test-rmse:88760.9
# [331]	train-rmse:87613.7	test-rmse:88760.5
# [332]	train-rmse:87610	test-rmse:88760
# [333]	train-rmse:87605.6	test-rmse:88759.4
# [334]	train-rmse:87603.4	test-rmse:88759.9
# [335]	train-rmse:87600.9	test-rmse:88760.1
# [336]	train-rmse:87600	test-rmse:88760.2
# [337]	train-rmse:87596.8	test-rmse:88759.6
# [338]	train-rmse:87594.5	test-rmse:88760.3
# [339]	train-rmse:87592.7	test-rmse:88760.6
# [340]	train-rmse:87589.5	test-rmse:88759.9
# [341]	train-rmse:87586.2	test-rmse:88759.6
# [342]	train-rmse:87585.8	test-rmse:88759.6
# [343]	train-rmse:87585.3	test-rmse:88759.7
# [344]	train-rmse:87584	test-rmse:88759.3
# [345]	train-rmse:87583.3	test-rmse:88758.9
# [346]	train-rmse:87581.5	test-rmse:88758.5
# [347]	train-rmse:87576.8	test-rmse:88758.4
# [348]	train-rmse:87574.2	test-rmse:88758.2
# [349]	train-rmse:87572.1	test-rmse:88758.5
# [350]	train-rmse:87569.4	test-rmse:88757.8
# [351]	train-rmse:87566.7	test-rmse:88758.3
# [352]	train-rmse:87564.7	test-rmse:88758.6
# [353]	train-rmse:87561.3	test-rmse:88758.5
# [354]	train-rmse:87558.6	test-rmse:88758.4
# [355]	train-rmse:87558	test-rmse:88758.7
# [356]	train-rmse:87555.4	test-rmse:88758.1
# [357]	train-rmse:87552.5	test-rmse:88757.4
# [358]	train-rmse:87549.4	test-rmse:88757.4
# [359]	train-rmse:87546.9	test-rmse:88757.4
# [360]	train-rmse:87545.9	test-rmse:88757.3
# [361]	train-rmse:87543.8	test-rmse:88757.1
# [362]	train-rmse:87542.5	test-rmse:88757.4
# [363]	train-rmse:87541.2	test-rmse:88757.6
# [364]	train-rmse:87537.8	test-rmse:88757.9
# [365]	train-rmse:87535.7	test-rmse:88757.9
# [366]	train-rmse:87535.4	test-rmse:88757.9
# [367]	train-rmse:87533.3	test-rmse:88758
# [368]	train-rmse:87530.3	test-rmse:88756.8
# [369]	train-rmse:87528.8	test-rmse:88756.8
# [370]	train-rmse:87524.6	test-rmse:88756.8
# [371]	train-rmse:87522.2	test-rmse:88757
# [372]	train-rmse:87520.3	test-rmse:88757.1
# [373]	train-rmse:87517.4	test-rmse:88757.3
# [374]	train-rmse:87515.5	test-rmse:88757.4
# [375]	train-rmse:87514.1	test-rmse:88757
# [376]	train-rmse:87513.3	test-rmse:88757
# [377]	train-rmse:87510.4	test-rmse:88756.7
# [378]	train-rmse:87509.1	test-rmse:88756.8
# [379]	train-rmse:87506.4	test-rmse:88756.7
# [380]	train-rmse:87503.2	test-rmse:88756.7
# [381]	train-rmse:87501.4	test-rmse:88756.4
# [382]	train-rmse:87498.5	test-rmse:88756.5
# [383]	train-rmse:87496.6	test-rmse:88755.8
# [384]	train-rmse:87494.3	test-rmse:88755.6
# [385]	train-rmse:87492.2	test-rmse:88755.5
# [386]	train-rmse:87488.9	test-rmse:88755.3
# [387]	train-rmse:87487.6	test-rmse:88755.7
# [388]	train-rmse:87485.1	test-rmse:88755
# [389]	train-rmse:87482.3	test-rmse:88755.2
# [390]	train-rmse:87481.4	test-rmse:88755.4
# [391]	train-rmse:87479.2	test-rmse:88755.3
# [392]	train-rmse:87478.3	test-rmse:88755.4
# [393]	train-rmse:87477.8	test-rmse:88755.5
# [394]	train-rmse:87475.5	test-rmse:88755.1
# [395]	train-rmse:87473.1	test-rmse:88754.9
# [396]	train-rmse:87471.2	test-rmse:88754.6
# [397]	train-rmse:87470.7	test-rmse:88754.5
# [398]	train-rmse:87468.7	test-rmse:88754.3
# [399]	train-rmse:87468.4	test-rmse:88754.4
# [400]	train-rmse:87468	test-rmse:88754.7
# [401]	train-rmse:87466.2	test-rmse:88754.7
# [402]	train-rmse:87465.6	test-rmse:88754.8
# [403]	train-rmse:87462.4	test-rmse:88754
# [404]	train-rmse:87460	test-rmse:88753.8
# [405]	train-rmse:87456	test-rmse:88753.2
# [406]	train-rmse:87453.5	test-rmse:88752.9
# [407]	train-rmse:87451.3	test-rmse:88753
# [408]	train-rmse:87449.4	test-rmse:88753
# [409]	train-rmse:87445.6	test-rmse:88752.8
# [410]	train-rmse:87442.7	test-rmse:88752.9
# [411]	train-rmse:87439.5	test-rmse:88752.3
# [412]	train-rmse:87436.6	test-rmse:88751.7
# [413]	train-rmse:87433.9	test-rmse:88751.8
# [414]	train-rmse:87432.4	test-rmse:88751.9
# [415]	train-rmse:87429.5	test-rmse:88751.6
# [416]	train-rmse:87425.9	test-rmse:88751.4
# [417]	train-rmse:87423.3	test-rmse:88751.6
# [418]	train-rmse:87419.1	test-rmse:88751.2
# [419]	train-rmse:87416.8	test-rmse:88750.7
# [420]	train-rmse:87414.7	test-rmse:88750.4
# [421]	train-rmse:87411.3	test-rmse:88750.1
# [422]	train-rmse:87409.4	test-rmse:88749.8
# [423]	train-rmse:87406.9	test-rmse:88749.4
# [424]	train-rmse:87404.5	test-rmse:88749.4
# [425]	train-rmse:87402.5	test-rmse:88749
# [426]	train-rmse:87402	test-rmse:88748.9
# [427]	train-rmse:87400.2	test-rmse:88748.8
# [428]	train-rmse:87398.2	test-rmse:88748.1
# [429]	train-rmse:87395.6	test-rmse:88748.3
# [430]	train-rmse:87393.5	test-rmse:88748.7
# [431]	train-rmse:87391.3	test-rmse:88748.6
# [432]	train-rmse:87387.6	test-rmse:88747.9
# [433]	train-rmse:87384.4	test-rmse:88747.6
# [434]	train-rmse:87381.6	test-rmse:88747.7
# [435]	train-rmse:87379.2	test-rmse:88747.6
# [436]	train-rmse:87376.1	test-rmse:88747.1
# [437]	train-rmse:87373.4	test-rmse:88747.7
# [438]	train-rmse:87370.3	test-rmse:88746.2
# [439]	train-rmse:87368.4	test-rmse:88745.7
# [440]	train-rmse:87366.3	test-rmse:88745.7
# [441]	train-rmse:87364.4	test-rmse:88745.7
# [442]	train-rmse:87361.9	test-rmse:88745.2
# [443]	train-rmse:87361.6	test-rmse:88745.1
# [444]	train-rmse:87361	test-rmse:88745.3
# [445]	train-rmse:87358.7	test-rmse:88744.8
# [446]	train-rmse:87356.1	test-rmse:88744.1
# [447]	train-rmse:87354.5	test-rmse:88744.2
# [448]	train-rmse:87354.2	test-rmse:88744.3
# [449]	train-rmse:87353.1	test-rmse:88744.4
# [450]	train-rmse:87351.3	test-rmse:88744.4
# [451]	train-rmse:87348.2	test-rmse:88744.6
# [452]	train-rmse:87346.7	test-rmse:88744.5
# [453]	train-rmse:87344.9	test-rmse:88744.3
# [454]	train-rmse:87343.3	test-rmse:88743.5
# [455]	train-rmse:87340.1	test-rmse:88743.4
# [456]	train-rmse:87336.5	test-rmse:88742.8
# [457]	train-rmse:87333.6	test-rmse:88742.8
# [458]	train-rmse:87330	test-rmse:88741.8
# [459]	train-rmse:87327.6	test-rmse:88742.7
# [460]	train-rmse:87325.2	test-rmse:88742.2
# [461]	train-rmse:87323.2	test-rmse:88741.8
# [462]	train-rmse:87320.2	test-rmse:88741.2
# [463]	train-rmse:87318	test-rmse:88740.6
# [464]	train-rmse:87316.4	test-rmse:88740.6
# [465]	train-rmse:87313.3	test-rmse:88740.4
# [466]	train-rmse:87312.9	test-rmse:88740.4
# [467]	train-rmse:87311.6	test-rmse:88740.4
# [468]	train-rmse:87311	test-rmse:88740.4
# [469]	train-rmse:87309.2	test-rmse:88740.6
# [470]	train-rmse:87307.7	test-rmse:88740.2
# [471]	train-rmse:87304.4	test-rmse:88740.1
# [472]	train-rmse:87303.9	test-rmse:88740.4
# [473]	train-rmse:87301.6	test-rmse:88740
# [474]	train-rmse:87299.8	test-rmse:88739.7
# [475]	train-rmse:87297.7	test-rmse:88739.4
# [476]	train-rmse:87294.8	test-rmse:88739.6
# [477]	train-rmse:87294.6	test-rmse:88739.7
# [478]	train-rmse:87292.7	test-rmse:88739.3
# [479]	train-rmse:87291.4	test-rmse:88739
# [480]	train-rmse:87291.2	test-rmse:88739.2
# [481]	train-rmse:87290.3	test-rmse:88739.3
# [482]	train-rmse:87288.3	test-rmse:88739.4
# [483]	train-rmse:87285.7	test-rmse:88739.5
# [484]	train-rmse:87283.6	test-rmse:88739.6
# [485]	train-rmse:87280.8	test-rmse:88739.3
# [486]	train-rmse:87276.1	test-rmse:88738.2
# [487]	train-rmse:87273.5	test-rmse:88738.1
# [488]	train-rmse:87272.1	test-rmse:88737.8
# [489]	train-rmse:87271.7	test-rmse:88737.8
# [490]	train-rmse:87271.3	test-rmse:88737.7
# [491]	train-rmse:87268.8	test-rmse:88737.2
# [492]	train-rmse:87268	test-rmse:88737.1
# [493]	train-rmse:87267.1	test-rmse:88737
# [494]	train-rmse:87265.2	test-rmse:88737
# [495]	train-rmse:87262.9	test-rmse:88736.9
# [496]	train-rmse:87258.9	test-rmse:88735.6
# [497]	train-rmse:87257.5	test-rmse:88735.9
# [498]	train-rmse:87255	test-rmse:88735.8
# [499]	train-rmse:87252.8	test-rmse:88735.9
# [500]	train-rmse:87251	test-rmse:88735.3
# [501]	train-rmse:87247.1	test-rmse:88734.4
# [502]	train-rmse:87244.7	test-rmse:88734.1
# [503]	train-rmse:87241.4	test-rmse:88733.6
# [504]	train-rmse:87238.5	test-rmse:88733.3
# [505]	train-rmse:87236.5	test-rmse:88733.5
# [506]	train-rmse:87234.1	test-rmse:88733.7
# [507]	train-rmse:87231.8	test-rmse:88733.4
# [508]	train-rmse:87228.6	test-rmse:88733.9
# [509]	train-rmse:87226.8	test-rmse:88734.4
# [510]	train-rmse:87225	test-rmse:88733.8
# [511]	train-rmse:87222.7	test-rmse:88734
# [512]	train-rmse:87221.1	test-rmse:88734
# [513]	train-rmse:87217.4	test-rmse:88732.8
# [514]	train-rmse:87214	test-rmse:88732.7
# [515]	train-rmse:87211.6	test-rmse:88732.9
# [516]	train-rmse:87209.9	test-rmse:88732.9
# [517]	train-rmse:87207.1	test-rmse:88732.6
# [518]	train-rmse:87205.5	test-rmse:88732.7
# [519]	train-rmse:87203.1	test-rmse:88732.3
# [520]	train-rmse:87201.3	test-rmse:88732
# [521]	train-rmse:87199.3	test-rmse:88732.3
# [522]	train-rmse:87196	test-rmse:88732.2
# [523]	train-rmse:87193.5	test-rmse:88731.9
# [524]	train-rmse:87190.8	test-rmse:88731.3
# [525]	train-rmse:87187.9	test-rmse:88731.8
# [526]	train-rmse:87186.3	test-rmse:88731.5
# [527]	train-rmse:87183.4	test-rmse:88730.4
# [528]	train-rmse:87181.3	test-rmse:88730.2
# [529]	train-rmse:87178.4	test-rmse:88729.7
# [530]	train-rmse:87176.1	test-rmse:88729.4
# [531]	train-rmse:87173.4	test-rmse:88729.1
# [532]	train-rmse:87170.5	test-rmse:88728.8
# [533]	train-rmse:87168.3	test-rmse:88728.9
# [534]	train-rmse:87166.2	test-rmse:88728
# [535]	train-rmse:87163.5	test-rmse:88727.7
# [536]	train-rmse:87162.8	test-rmse:88727.8
# [537]	train-rmse:87161.7	test-rmse:88728.2
# [538]	train-rmse:87160.1	test-rmse:88728.4
# [539]	train-rmse:87158.1	test-rmse:88728.2
# [540]	train-rmse:87155.5	test-rmse:88727.7
# [541]	train-rmse:87153.7	test-rmse:88727.5
# [542]	train-rmse:87152.4	test-rmse:88727.8
# [543]	train-rmse:87150.1	test-rmse:88727.2
# [544]	train-rmse:87147.2	test-rmse:88727
# [545]	train-rmse:87145.8	test-rmse:88726.6
# [546]	train-rmse:87144.1	test-rmse:88726.3
# [547]	train-rmse:87141.3	test-rmse:88725.9
# [548]	train-rmse:87141.1	test-rmse:88725.9
# [549]	train-rmse:87140.8	test-rmse:88725.9
# [550]	train-rmse:87139.8	test-rmse:88725.7
# [551]	train-rmse:87137.4	test-rmse:88725.2
# [552]	train-rmse:87135.5	test-rmse:88725.2
# [553]	train-rmse:87132.9	test-rmse:88725.3
# [554]	train-rmse:87130.4	test-rmse:88725.2
# [555]	train-rmse:87127.9	test-rmse:88724.8
# [556]	train-rmse:87124.8	test-rmse:88724.3
# [557]	train-rmse:87122.9	test-rmse:88724.1
# [558]	train-rmse:87120.3	test-rmse:88723.7
# [559]	train-rmse:87118.5	test-rmse:88723.2
# [560]	train-rmse:87116.6	test-rmse:88723
# [561]	train-rmse:87113.8	test-rmse:88723.1
# [562]	train-rmse:87111.1	test-rmse:88723.2
# [563]	train-rmse:87109	test-rmse:88723.2
# [564]	train-rmse:87107.3	test-rmse:88723.5
# [565]	train-rmse:87104.9	test-rmse:88723.8
# [566]	train-rmse:87103.2	test-rmse:88724.4
# [567]	train-rmse:87100.9	test-rmse:88724.8
# [568]	train-rmse:87100.6	test-rmse:88724.6
# [569]	train-rmse:87098.3	test-rmse:88725
# [570]	train-rmse:87097.2	test-rmse:88724.6
# [571]	train-rmse:87094.2	test-rmse:88724.3
# [572]	train-rmse:87090.5	test-rmse:88723.3
# [573]	train-rmse:87088.6	test-rmse:88723.1
# [574]	train-rmse:87086.1	test-rmse:88722.8
# [575]	train-rmse:87084.3	test-rmse:88722.2
# [576]	train-rmse:87081.5	test-rmse:88722.1
# [577]	train-rmse:87078.5	test-rmse:88721.8
# [578]	train-rmse:87078.2	test-rmse:88721.8
# [579]	train-rmse:87076.5	test-rmse:88721.5
# [580]	train-rmse:87073	test-rmse:88721.1
# [581]	train-rmse:87070.6	test-rmse:88721
# [582]	train-rmse:87069.5	test-rmse:88721.1
# [583]	train-rmse:87067.9	test-rmse:88721.3
# [584]	train-rmse:87066.4	test-rmse:88721.8
# [585]	train-rmse:87065.8	test-rmse:88721.8
# [586]	train-rmse:87062.1	test-rmse:88721.2
# [587]	train-rmse:87059.4	test-rmse:88720.8
# [588]	train-rmse:87057.6	test-rmse:88720.1
# [589]	train-rmse:87055.6	test-rmse:88719.3
# [590]	train-rmse:87053.6	test-rmse:88719.5
# [591]	train-rmse:87052.6	test-rmse:88719.6
# [592]	train-rmse:87051	test-rmse:88719.5
# [593]	train-rmse:87048.1	test-rmse:88719.3
# [594]	train-rmse:87045.9	test-rmse:88719
# [595]	train-rmse:87044.1	test-rmse:88718.7
# [596]	train-rmse:87041.7	test-rmse:88718.5
# [597]	train-rmse:87040.8	test-rmse:88718.3
# [598]	train-rmse:87039.3	test-rmse:88717.7
# [599]	train-rmse:87037.4	test-rmse:88717.5
# [600]	train-rmse:87037	test-rmse:88717.5
# [601]	train-rmse:87034.5	test-rmse:88717
# [602]	train-rmse:87032.2	test-rmse:88717.3
# [603]	train-rmse:87031	test-rmse:88717.5
# [604]	train-rmse:87027.7	test-rmse:88717
# [605]	train-rmse:87025.6	test-rmse:88717
# [606]	train-rmse:87023.9	test-rmse:88717
# [607]	train-rmse:87021.9	test-rmse:88716.6
# [608]	train-rmse:87020.7	test-rmse:88716.5
# [609]	train-rmse:87018.8	test-rmse:88715.9
# [610]	train-rmse:87016.4	test-rmse:88715.5
# [611]	train-rmse:87014.8	test-rmse:88715.4
# [612]	train-rmse:87013.5	test-rmse:88714.9
# [613]	train-rmse:87010.7	test-rmse:88713.8
# [614]	train-rmse:87008.5	test-rmse:88713.4
# [615]	train-rmse:87005.9	test-rmse:88713.3
# [616]	train-rmse:87002.8	test-rmse:88713.2
# [617]	train-rmse:86999.8	test-rmse:88713.6
# [618]	train-rmse:86999.4	test-rmse:88713.7
# [619]	train-rmse:86998.4	test-rmse:88713.6
# [620]	train-rmse:86995.7	test-rmse:88713.3
# [621]	train-rmse:86993.1	test-rmse:88713.7
# [622]	train-rmse:86992.1	test-rmse:88713.8
# [623]	train-rmse:86988.7	test-rmse:88713.3
# [624]	train-rmse:86985.7	test-rmse:88712.7
# [625]	train-rmse:86982.4	test-rmse:88712.5
# [626]	train-rmse:86978.9	test-rmse:88711.8
# [627]	train-rmse:86975.4	test-rmse:88711.5
# [628]	train-rmse:86974.4	test-rmse:88711.4
# [629]	train-rmse:86971.5	test-rmse:88711
# [630]	train-rmse:86969.5	test-rmse:88710.8
# [631]	train-rmse:86966	test-rmse:88711
# [632]	train-rmse:86962.8	test-rmse:88710.3
# [633]	train-rmse:86960.9	test-rmse:88710.1
# [634]	train-rmse:86958.7	test-rmse:88709.9
# [635]	train-rmse:86956.5	test-rmse:88709.7
# [636]	train-rmse:86954.4	test-rmse:88709.6
# [637]	train-rmse:86951.3	test-rmse:88708.9
# [638]	train-rmse:86949.5	test-rmse:88709.1
# [639]	train-rmse:86947.1	test-rmse:88709.1
# [640]	train-rmse:86945.3	test-rmse:88708.5
# [641]	train-rmse:86943.3	test-rmse:88708.2
# [642]	train-rmse:86940.6	test-rmse:88708
# [643]	train-rmse:86938.9	test-rmse:88708.3
# [644]	train-rmse:86937.1	test-rmse:88707.9
# [645]	train-rmse:86935.9	test-rmse:88708.1
# [646]	train-rmse:86932.8	test-rmse:88708.3
# [647]	train-rmse:86930.8	test-rmse:88708.2
# [648]	train-rmse:86930.4	test-rmse:88708.3
# [649]	train-rmse:86928.9	test-rmse:88708.5
# [650]	train-rmse:86927.5	test-rmse:88708.4
# [651]	train-rmse:86925.4	test-rmse:88708.5
# [652]	train-rmse:86923.9	test-rmse:88708.3
# [653]	train-rmse:86920.9	test-rmse:88708.4
# [654]	train-rmse:86919.2	test-rmse:88708.3
# [655]	train-rmse:86917.7	test-rmse:88708.4
# [656]	train-rmse:86914.6	test-rmse:88708.2
# [657]	train-rmse:86911.3	test-rmse:88707.9
# [658]	train-rmse:86909.2	test-rmse:88708.1
# [659]	train-rmse:86905.6	test-rmse:88707.7
# [660]	train-rmse:86904.4	test-rmse:88707.4
# [661]	train-rmse:86902.5	test-rmse:88707.4
# [662]	train-rmse:86901.2	test-rmse:88707.3
# [663]	train-rmse:86898.5	test-rmse:88706.2
# [664]	train-rmse:86896.9	test-rmse:88706.3
# [665]	train-rmse:86893.8	test-rmse:88706.2
# [666]	train-rmse:86891.4	test-rmse:88706.1
# [667]	train-rmse:86890.7	test-rmse:88706
# [668]	train-rmse:86889.6	test-rmse:88705.9
# [669]	train-rmse:86888.1	test-rmse:88706.2
# [670]	train-rmse:86886	test-rmse:88706.2
# [671]	train-rmse:86884.1	test-rmse:88706.2
# [672]	train-rmse:86882.6	test-rmse:88706.1
# [673]	train-rmse:86880.8	test-rmse:88705.7
# [674]	train-rmse:86878.5	test-rmse:88704.8
# [675]	train-rmse:86877.4	test-rmse:88704.9
# [676]	train-rmse:86876.6	test-rmse:88704.8
# [677]	train-rmse:86876.1	test-rmse:88704.7
# [678]	train-rmse:86874.9	test-rmse:88704.9
# [679]	train-rmse:86872.7	test-rmse:88704.5
# [680]	train-rmse:86870.9	test-rmse:88704.2
# [681]	train-rmse:86869.3	test-rmse:88703.9
# [682]	train-rmse:86868.9	test-rmse:88704.2
# [683]	train-rmse:86867.3	test-rmse:88704.1
# [684]	train-rmse:86864.9	test-rmse:88703.7
# [685]	train-rmse:86862.3	test-rmse:88703.4
# [686]	train-rmse:86860.5	test-rmse:88704.1
# [687]	train-rmse:86858.1	test-rmse:88704.8
# [688]	train-rmse:86855.5	test-rmse:88704.6
# [689]	train-rmse:86854.2	test-rmse:88704.3
# [690]	train-rmse:86852.9	test-rmse:88704.4
# [691]	train-rmse:86850.8	test-rmse:88704.1
# [692]	train-rmse:86849.1	test-rmse:88703.9
# [693]	train-rmse:86847.5	test-rmse:88703.7
# [694]	train-rmse:86844.1	test-rmse:88703.5
# [695]	train-rmse:86841	test-rmse:88703
# [696]	train-rmse:86838.4	test-rmse:88702.8
# [697]	train-rmse:86836.3	test-rmse:88703
# [698]	train-rmse:86835.4	test-rmse:88703.1
# [699]	train-rmse:86832.7	test-rmse:88703.2
# [700]	train-rmse:86829.9	test-rmse:88703.2
# [701]	train-rmse:86827.3	test-rmse:88702.7
# [702]	train-rmse:86825.9	test-rmse:88702.4
# [703]	train-rmse:86823.2	test-rmse:88702.2
# [704]	train-rmse:86821.8	test-rmse:88702.2
# [705]	train-rmse:86819.7	test-rmse:88701.8
# [706]	train-rmse:86818.5	test-rmse:88702
# [707]	train-rmse:86817.3	test-rmse:88702
# [708]	train-rmse:86815.3	test-rmse:88701.5
# [709]	train-rmse:86813.8	test-rmse:88701.9
# [710]	train-rmse:86812.2	test-rmse:88701.7
# [711]	train-rmse:86809.8	test-rmse:88701.4
# [712]	train-rmse:86809	test-rmse:88701.5
# [713]	train-rmse:86807.2	test-rmse:88701.8
# [714]	train-rmse:86805.7	test-rmse:88701.5
# [715]	train-rmse:86803.9	test-rmse:88701
# [716]	train-rmse:86801.1	test-rmse:88701.3
# [717]	train-rmse:86799.1	test-rmse:88701.3
# [718]	train-rmse:86796.3	test-rmse:88701
# [719]	train-rmse:86794.2	test-rmse:88701.2
# [720]	train-rmse:86793	test-rmse:88701.5
# [721]	train-rmse:86790.9	test-rmse:88701.7
# [722]	train-rmse:86789	test-rmse:88701.4
# [723]	train-rmse:86786.6	test-rmse:88701.3
# [724]	train-rmse:86785	test-rmse:88701
# [725]	train-rmse:86781.9	test-rmse:88701
# [726]	train-rmse:86781.1	test-rmse:88701
# [727]	train-rmse:86779.9	test-rmse:88701.1
# [728]	train-rmse:86777.2	test-rmse:88700.8
# [729]	train-rmse:86774.8	test-rmse:88700.9
# [730]	train-rmse:86772.5	test-rmse:88701.2
# [731]	train-rmse:86771.4	test-rmse:88701.2
# [732]	train-rmse:86770.2	test-rmse:88701.5
# [733]	train-rmse:86768.8	test-rmse:88701.5
# [734]	train-rmse:86768.5	test-rmse:88701.6
# [735]	train-rmse:86765.7	test-rmse:88701.3
# [736]	train-rmse:86764.5	test-rmse:88701.3
# [737]	train-rmse:86762.3	test-rmse:88701.4
# [738]	train-rmse:86760.5	test-rmse:88701.1
# [739]	train-rmse:86758.1	test-rmse:88701.3
# [740]	train-rmse:86755.2	test-rmse:88702.1
# [741]	train-rmse:86753.3	test-rmse:88702.1
# [742]	train-rmse:86752.6	test-rmse:88702.2
# [743]	train-rmse:86751.8	test-rmse:88702.4
# [744]	train-rmse:86750.2	test-rmse:88702.9
# [745]	train-rmse:86749.4	test-rmse:88702.9
# [746]	train-rmse:86748.1	test-rmse:88702.8
# [747]	train-rmse:86746.5	test-rmse:88702.3
# [748]	train-rmse:86744.4	test-rmse:88702
# Stopping. Best iteration:
# [728]	train-rmse:86777.2	test-rmse:88700.8

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Pruebas agregando ventana 5

# %% [markdown]
# ### Pruebas para modelo 001 conversion (Todos los features)

# %%
train = pd.read_pickle("../../../modelo/armado_datos/train_completo_installs.pkl")

# %%
ventana5 = pd.read_pickle("../../../modelo/armado_datos/train_ventana_5_reales_installs.pkl")

# %%
train = train.append(ventana5)

# %%
train.shape
# Out:
# (1145693, 104)

# %%
train["cantidad_nans"] = train.isnull().sum(axis=1)

# %%
train["cantidad_nans"].max()
# Out:
# 103

# %%
train_reducido = train[train["cantidad_nans"] < 103]

# %%
len(train_reducido)
# Out:
# 778580

# %%
X, y = train_reducido.drop("target",axis = 1), train_reducido["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

# %%
len(y_test)
# Out:
# 155716

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)

#La mejor
# Datos sacando las filas que tienen todos los nans
#[99]	train-rmse:48100	test-rmse:48482.6
# len 778 mil

#Datos completos con nans
#[94]	train-rmse:56717.6	test-rmse:57109.4
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:204811	test-rmse:204880
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:185531	test-rmse:185604
# [2]	train-rmse:168284	test-rmse:168398
# [3]	train-rmse:152926	test-rmse:153032
# [4]	train-rmse:139266	test-rmse:139355
# [5]	train-rmse:127091	test-rmse:127198
# [6]	train-rmse:116317	test-rmse:116433
# [7]	train-rmse:106798	test-rmse:106910
# [8]	train-rmse:98422.3	test-rmse:98524.6
# [9]	train-rmse:91051.5	test-rmse:91170
# [10]	train-rmse:84627.7	test-rmse:84743.4
# [11]	train-rmse:79037	test-rmse:79156.8
# [12]	train-rmse:74191.3	test-rmse:74323.7
# [13]	train-rmse:70033.5	test-rmse:70162.4
# [14]	train-rmse:66458.6	test-rmse:66597.5
# [15]	train-rmse:63424.2	test-rmse:63564.5
# [16]	train-rmse:60848	test-rmse:60992.2
# [17]	train-rmse:58676.6	test-rmse:58829.4
# [18]	train-rmse:56863.8	test-rmse:57019.2
# [19]	train-rmse:55356.3	test-rmse:55507.5
# [20]	train-rmse:54094.3	test-rmse:54250.2
# [21]	train-rmse:53052.5	test-rmse:53211.4
# [22]	train-rmse:52187.7	test-rmse:52350.1
# [23]	train-rmse:51475.1	test-rmse:51643.5
# [24]	train-rmse:50894.8	test-rmse:51064.5
# [25]	train-rmse:50418.8	test-rmse:50590.5
# [26]	train-rmse:50031.3	test-rmse:50201
# [27]	train-rmse:49705.4	test-rmse:49883.7
# [28]	train-rmse:49441.8	test-rmse:49624.6
# [29]	train-rmse:49226.6	test-rmse:49412.9
# [30]	train-rmse:49055.1	test-rmse:49240.9
# [31]	train-rmse:48914.4	test-rmse:49101.1
# [32]	train-rmse:48796	test-rmse:48987.4
# [33]	train-rmse:48700	test-rmse:48894.7
# [34]	train-rmse:48620.3	test-rmse:48819
# [35]	train-rmse:48557	test-rmse:48758.2
# [36]	train-rmse:48502.9	test-rmse:48708.4
# [37]	train-rmse:48462.1	test-rmse:48667.8
# [38]	train-rmse:48423.2	test-rmse:48634.3
# [39]	train-rmse:48393.4	test-rmse:48607.6
# [40]	train-rmse:48367.6	test-rmse:48585.9
# [41]	train-rmse:48349.9	test-rmse:48568.9
# [42]	train-rmse:48329.9	test-rmse:48555.2
# [43]	train-rmse:48314.8	test-rmse:48543.9
# [44]	train-rmse:48303	test-rmse:48534
# [45]	train-rmse:48293.2	test-rmse:48526.6
# [46]	train-rmse:48280.2	test-rmse:48520.5
# [47]	train-rmse:48271.8	test-rmse:48514.5
# [48]	train-rmse:48264.9	test-rmse:48510.5
# [49]	train-rmse:48258.7	test-rmse:48506.9
# [50]	train-rmse:48254.4	test-rmse:48504.1
# [51]	train-rmse:48247.4	test-rmse:48500.7
# [52]	train-rmse:48243.9	test-rmse:48498.7
# [53]	train-rmse:48237.9	test-rmse:48496.7
# [54]	train-rmse:48233.9	test-rmse:48494.9
# [55]	train-rmse:48226.5	test-rmse:48493.5
# [56]	train-rmse:48220.7	test-rmse:48492.4
# [57]	train-rmse:48215.3	test-rmse:48491.4
# [58]	train-rmse:48210.6	test-rmse:48490.5
# [59]	train-rmse:48205.5	test-rmse:48490.3
# [60]	train-rmse:48202.9	test-rmse:48490.8
# [61]	train-rmse:48200.3	test-rmse:48490.6
# [62]	train-rmse:48197.9	test-rmse:48491.3
# [63]	train-rmse:48194.4	test-rmse:48490.9
# [64]	train-rmse:48191.1	test-rmse:48490.2
# [65]	train-rmse:48187	test-rmse:48489.5
# [66]	train-rmse:48182.3	test-rmse:48488
# [67]	train-rmse:48180.7	test-rmse:48487.8
# [68]	train-rmse:48179.8	test-rmse:48487.8
# [69]	train-rmse:48178.4	test-rmse:48487.9
# [70]	train-rmse:48176	test-rmse:48487.2
# [71]	train-rmse:48175	test-rmse:48487.3
# [72]	train-rmse:48170.7	test-rmse:48486.9
# [73]	train-rmse:48166.8	test-rmse:48485.7
# [74]	train-rmse:48164.2	test-rmse:48486
# [75]	train-rmse:48161.6	test-rmse:48485.8
# [76]	train-rmse:48158.1	test-rmse:48485.1
# [77]	train-rmse:48156.1	test-rmse:48484.2
# [78]	train-rmse:48155.3	test-rmse:48484.4
# [79]	train-rmse:48150	test-rmse:48483.8
# [80]	train-rmse:48147.2	test-rmse:48483.8
# [81]	train-rmse:48145	test-rmse:48484.1
# [82]	train-rmse:48140.7	test-rmse:48484.5
# [83]	train-rmse:48137	test-rmse:48484.6
# [84]	train-rmse:48135.7	test-rmse:48483.9
# [85]	train-rmse:48132.1	test-rmse:48483.6
# [86]	train-rmse:48128.5	test-rmse:48483.7
# [87]	train-rmse:48126.4	test-rmse:48483.1
# [88]	train-rmse:48123.7	test-rmse:48483.5
# [89]	train-rmse:48120.1	test-rmse:48483.3
# [90]	train-rmse:48118.1	test-rmse:48483.9
# [91]	train-rmse:48116.4	test-rmse:48484
# [92]	train-rmse:48115.8	test-rmse:48484.2
# [93]	train-rmse:48113.5	test-rmse:48483.4
# [94]	train-rmse:48111.4	test-rmse:48483.4
# [95]	train-rmse:48109.8	test-rmse:48483.5
# [96]	train-rmse:48108.5	test-rmse:48483.7
# [97]	train-rmse:48107.4	test-rmse:48483.6
# [98]	train-rmse:48103.3	test-rmse:48482.7
# [99]	train-rmse:48100	test-rmse:48482.6
# [100]	train-rmse:48098.1	test-rmse:48482.8
# [101]	train-rmse:48096.7	test-rmse:48483.2
# [102]	train-rmse:48094.9	test-rmse:48483.8
# [103]	train-rmse:48093.2	test-rmse:48483.8
# [104]	train-rmse:48090	test-rmse:48483.2
# [105]	train-rmse:48088.4	test-rmse:48483.2
# [106]	train-rmse:48086.4	test-rmse:48483.4
# [107]	train-rmse:48085.6	test-rmse:48483.3
# [108]	train-rmse:48082.6	test-rmse:48484.1
# [109]	train-rmse:48081.4	test-rmse:48483.6
# [110]	train-rmse:48078.4	test-rmse:48483.6
# [111]	train-rmse:48074.9	test-rmse:48483.8
# [112]	train-rmse:48073.4	test-rmse:48484.2
# [113]	train-rmse:48072.6	test-rmse:48484.3
# [114]	train-rmse:48070.3	test-rmse:48484.4
# [115]	train-rmse:48066.5	test-rmse:48483.9
# [116]	train-rmse:48065.5	test-rmse:48484.1
# [117]	train-rmse:48064.7	test-rmse:48484.4
# [118]	train-rmse:48061.6	test-rmse:48484.1
# [119]	train-rmse:48057.7	test-rmse:48484.2
# Stopping. Best iteration:
# [99]	train-rmse:48100	test-rmse:48482.6

# %% [markdown]
# ---

# %% [markdown]
# ### Pruebas para modelo 001 auctions(Todos los features)

# %%
train = pd.read_pickle("../../../modelo/armado_datos/train_completo_auctions.pkl")

# %%
ventana5 = pd.read_pickle("../../../modelo/armado_datos/train_ventana_5_reales_auctions.pkl")

# %%
train = train.append(ventana5)

# %%
train.shape
# Out:
# (1500281, 104)

# %%
train["cantidad_nans"] = train.isnull().sum(axis=1)

# %%
train["cantidad_nans"].max()
# Out:
# 57

# %%
X, y = train.drop("target",axis = 1), train["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

# %%
len(y_test)
# Out:
# 300057

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)

#La mejor
# Datos sacando las filas que tienen todos los nans
#[99]	train-rmse:48100	test-rmse:48482.6
# len 778 mil

#Datos completos con nans
#[94]	train-rmse:56717.6	test-rmse:57109.4
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:140051	test-rmse:140262
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:131769	test-rmse:131977
# [2]	train-rmse:124680	test-rmse:124872
# [3]	train-rmse:118592	test-rmse:118780
# [4]	train-rmse:113419	test-rmse:113617
# [5]	train-rmse:109005	test-rmse:109231
# [6]	train-rmse:105319	test-rmse:105547
# [7]	train-rmse:102204	test-rmse:102444
# [8]	train-rmse:99610.3	test-rmse:99855
# [9]	train-rmse:97442.2	test-rmse:97698
# [10]	train-rmse:95650.8	test-rmse:95913.7
# [11]	train-rmse:94158.2	test-rmse:94431.4
# [12]	train-rmse:92924.8	test-rmse:93204.9
# [13]	train-rmse:91914.7	test-rmse:92200.5
# [14]	train-rmse:91081.8	test-rmse:91375
# [15]	train-rmse:90395	test-rmse:90694.9
# [16]	train-rmse:89827.9	test-rmse:90133.4
# [17]	train-rmse:89357.6	test-rmse:89665.8
# [18]	train-rmse:88968.3	test-rmse:89282.5
# [19]	train-rmse:88649.2	test-rmse:88971.4
# [20]	train-rmse:88385.3	test-rmse:88710.9
# [21]	train-rmse:88168.6	test-rmse:88497.6
# [22]	train-rmse:87987.6	test-rmse:88318.7
# [23]	train-rmse:87836.1	test-rmse:88171.4
# [24]	train-rmse:87709.5	test-rmse:88050.1
# [25]	train-rmse:87606.4	test-rmse:87948.8
# [26]	train-rmse:87519.2	test-rmse:87868.2
# [27]	train-rmse:87444.8	test-rmse:87795.3
# [28]	train-rmse:87374.5	test-rmse:87729.2
# [29]	train-rmse:87320.5	test-rmse:87677.4
# [30]	train-rmse:87273.7	test-rmse:87634.9
# [31]	train-rmse:87234.8	test-rmse:87600.5
# [32]	train-rmse:87203.4	test-rmse:87571.9
# [33]	train-rmse:87170.2	test-rmse:87542.8
# [34]	train-rmse:87144.7	test-rmse:87520.4
# [35]	train-rmse:87123.3	test-rmse:87502.1
# [36]	train-rmse:87100.8	test-rmse:87486.6
# [37]	train-rmse:87083.8	test-rmse:87472.1
# [38]	train-rmse:87065.2	test-rmse:87459.3
# [39]	train-rmse:87050.8	test-rmse:87446.8
# [40]	train-rmse:87036.4	test-rmse:87435.2
# [41]	train-rmse:87022.6	test-rmse:87425.4
# [42]	train-rmse:86999.9	test-rmse:87404.8
# [43]	train-rmse:86987	test-rmse:87395.5
# [44]	train-rmse:86971.5	test-rmse:87382.9
# [45]	train-rmse:86961.3	test-rmse:87376.8
# [46]	train-rmse:86948.6	test-rmse:87365.5
# [47]	train-rmse:86937.9	test-rmse:87357.9
# [48]	train-rmse:86928.2	test-rmse:87352.2
# [49]	train-rmse:86918.8	test-rmse:87346.4
# [50]	train-rmse:86909.5	test-rmse:87338.9
# [51]	train-rmse:86900.4	test-rmse:87332.8
# [52]	train-rmse:86891.2	test-rmse:87327.4
# [53]	train-rmse:86882.3	test-rmse:87321.1
# [54]	train-rmse:86870	test-rmse:87312.9
# [55]	train-rmse:86861	test-rmse:87307.5
# [56]	train-rmse:86853.1	test-rmse:87301.1
# [57]	train-rmse:86846.1	test-rmse:87297.7
# [58]	train-rmse:86838.7	test-rmse:87292.4
# [59]	train-rmse:86829.6	test-rmse:87286.8
# [60]	train-rmse:86822.5	test-rmse:87283.8
# [61]	train-rmse:86815	test-rmse:87279.9
# [62]	train-rmse:86809	test-rmse:87276.4
# [63]	train-rmse:86803.1	test-rmse:87272.8
# [64]	train-rmse:86794.5	test-rmse:87266.9
# [65]	train-rmse:86785.1	test-rmse:87260.2
# [66]	train-rmse:86775.7	test-rmse:87253.4
# [67]	train-rmse:86770.6	test-rmse:87251.2
# [68]	train-rmse:86764.7	test-rmse:87248.7
# [69]	train-rmse:86757.2	test-rmse:87244.3
# [70]	train-rmse:86750.8	test-rmse:87241
# [71]	train-rmse:86745.5	test-rmse:87238.1
# [72]	train-rmse:86739.3	test-rmse:87234.4
# [73]	train-rmse:86733.3	test-rmse:87231.5
# [74]	train-rmse:86726.8	test-rmse:87228.6
# [75]	train-rmse:86722.9	test-rmse:87226.7
# [76]	train-rmse:86717.3	test-rmse:87223.7
# [77]	train-rmse:86711.4	test-rmse:87220.7
# [78]	train-rmse:86704.6	test-rmse:87218.2
# [79]	train-rmse:86699	test-rmse:87215.7
# [80]	train-rmse:86693.8	test-rmse:87214.3
# [81]	train-rmse:86690	test-rmse:87212.2
# [82]	train-rmse:86684.2	test-rmse:87209.3
# [83]	train-rmse:86679.9	test-rmse:87208.8
# [84]	train-rmse:86676.8	test-rmse:87207.4
# [85]	train-rmse:86674.5	test-rmse:87206.6
# [86]	train-rmse:86669.1	test-rmse:87204.6
# [87]	train-rmse:86662.4	test-rmse:87200.9
# [88]	train-rmse:86659	test-rmse:87199.4
# [89]	train-rmse:86654.1	test-rmse:87197.4
# [90]	train-rmse:86650.1	test-rmse:87195.3
# [91]	train-rmse:86644.5	test-rmse:87193.4
# [92]	train-rmse:86638.7	test-rmse:87191.4
# [93]	train-rmse:86634.1	test-rmse:87190.2
# [94]	train-rmse:86628.9	test-rmse:87189.1
# [95]	train-rmse:86624.6	test-rmse:87187.5
# [96]	train-rmse:86616.9	test-rmse:87183.2
# [97]	train-rmse:86612.9	test-rmse:87181.1
# [98]	train-rmse:86607.2	test-rmse:87179.6
# [99]	train-rmse:86602.8	test-rmse:87177.8
# [100]	train-rmse:86600.6	test-rmse:87176.3
# [101]	train-rmse:86594.5	test-rmse:87173.8
# [102]	train-rmse:86590.2	test-rmse:87171.7
# [103]	train-rmse:86586.8	test-rmse:87170.7
# [104]	train-rmse:86580.7	test-rmse:87167.9
# [105]	train-rmse:86575.4	test-rmse:87165.9
# [106]	train-rmse:86572.1	test-rmse:87164.9
# [107]	train-rmse:86568.1	test-rmse:87164.2
# [108]	train-rmse:86564	test-rmse:87162.7
# [109]	train-rmse:86562.1	test-rmse:87161.9
# [110]	train-rmse:86561.4	test-rmse:87161.7
# [111]	train-rmse:86559.7	test-rmse:87161.4
# [112]	train-rmse:86554.2	test-rmse:87159.4
# [113]	train-rmse:86549.1	test-rmse:87157.8
# [114]	train-rmse:86544.5	test-rmse:87154.7
# [115]	train-rmse:86539.6	test-rmse:87153.4
# [116]	train-rmse:86535.9	test-rmse:87152.1
# [117]	train-rmse:86531.1	test-rmse:87149.6
# [118]	train-rmse:86527.9	test-rmse:87148.9
# [119]	train-rmse:86525.5	test-rmse:87148.4
# [120]	train-rmse:86523.1	test-rmse:87148.3
# [121]	train-rmse:86518.3	test-rmse:87146.8
# [122]	train-rmse:86515.4	test-rmse:87146.1
# [123]	train-rmse:86510.5	test-rmse:87144.2
# [124]	train-rmse:86506.4	test-rmse:87141.6
# [125]	train-rmse:86502.8	test-rmse:87140.4
# [126]	train-rmse:86501.6	test-rmse:87140.4
# [127]	train-rmse:86499.3	test-rmse:87140
# [128]	train-rmse:86496.3	test-rmse:87138.7
# [129]	train-rmse:86491.2	test-rmse:87137.7
# [130]	train-rmse:86486.8	test-rmse:87137
# [131]	train-rmse:86483.4	test-rmse:87135.6
# [132]	train-rmse:86478.7	test-rmse:87134.3
# [133]	train-rmse:86474.6	test-rmse:87133.1
# [134]	train-rmse:86470.9	test-rmse:87132.3
# [135]	train-rmse:86467.9	test-rmse:87131.7
# [136]	train-rmse:86464.5	test-rmse:87130.1
# [137]	train-rmse:86460.4	test-rmse:87129.3
# [138]	train-rmse:86455	test-rmse:87127.6
# [139]	train-rmse:86451.5	test-rmse:87127.2
# [140]	train-rmse:86447.6	test-rmse:87126.1
# [141]	train-rmse:86444.2	test-rmse:87125.3
# [142]	train-rmse:86440.6	test-rmse:87124.3
# [143]	train-rmse:86437.2	test-rmse:87123.7
# [144]	train-rmse:86434	test-rmse:87123.1
# [145]	train-rmse:86431.1	test-rmse:87122
# [146]	train-rmse:86428.4	test-rmse:87121.8
# [147]	train-rmse:86426.5	test-rmse:87121.8
# [148]	train-rmse:86421.8	test-rmse:87120.5
# [149]	train-rmse:86419.2	test-rmse:87120.6
# [150]	train-rmse:86418.1	test-rmse:87120.9
# [151]	train-rmse:86414.6	test-rmse:87121.1
# [152]	train-rmse:86413.1	test-rmse:87120.6
# [153]	train-rmse:86412.1	test-rmse:87120.7
# [154]	train-rmse:86409.4	test-rmse:87120.7
# [155]	train-rmse:86408.8	test-rmse:87120.8
# [156]	train-rmse:86406.4	test-rmse:87120.5
# [157]	train-rmse:86403.2	test-rmse:87120.3
# [158]	train-rmse:86399.4	test-rmse:87119
# [159]	train-rmse:86397.5	test-rmse:87118.7
# [160]	train-rmse:86394.6	test-rmse:87117.4
# [161]	train-rmse:86390.4	test-rmse:87116.5
# [162]	train-rmse:86385	test-rmse:87114.6
# [163]	train-rmse:86381	test-rmse:87112.6
# [164]	train-rmse:86378.7	test-rmse:87112.5
# [165]	train-rmse:86375.7	test-rmse:87111.1
# [166]	train-rmse:86372.4	test-rmse:87110.3
# [167]	train-rmse:86368.1	test-rmse:87109.3
# [168]	train-rmse:86365.2	test-rmse:87109.4
# [169]	train-rmse:86361	test-rmse:87108.9
# [170]	train-rmse:86356.5	test-rmse:87107.4
# [171]	train-rmse:86353.7	test-rmse:87107.4
# [172]	train-rmse:86352.8	test-rmse:87107.4
# [173]	train-rmse:86350.7	test-rmse:87106.6
# [174]	train-rmse:86346.8	test-rmse:87105.5
# [175]	train-rmse:86344.4	test-rmse:87105.5
# [176]	train-rmse:86341.8	test-rmse:87105.2
# [177]	train-rmse:86339.5	test-rmse:87105.2
# [178]	train-rmse:86336.7	test-rmse:87104.7
# [179]	train-rmse:86332.6	test-rmse:87103.2
# [180]	train-rmse:86331.4	test-rmse:87103.2
# [181]	train-rmse:86330.4	test-rmse:87103.1
# [182]	train-rmse:86328.3	test-rmse:87102.5
# [183]	train-rmse:86327.8	test-rmse:87102.4
# [184]	train-rmse:86324.8	test-rmse:87102.4
# [185]	train-rmse:86321	test-rmse:87101.8
# [186]	train-rmse:86318.7	test-rmse:87101.7
# [187]	train-rmse:86318.3	test-rmse:87101.8
# [188]	train-rmse:86314.9	test-rmse:87101.3
# [189]	train-rmse:86313.8	test-rmse:87101
# [190]	train-rmse:86310.3	test-rmse:87100.8
# [191]	train-rmse:86308	test-rmse:87100.9
# [192]	train-rmse:86307.6	test-rmse:87100.9
# [193]	train-rmse:86302.6	test-rmse:87099.5
# [194]	train-rmse:86299.5	test-rmse:87100.1
# [195]	train-rmse:86296.3	test-rmse:87100
# [196]	train-rmse:86291.5	test-rmse:87098.8
# [197]	train-rmse:86289.5	test-rmse:87099
# [198]	train-rmse:86285.9	test-rmse:87098
# [199]	train-rmse:86283	test-rmse:87097.5
# [200]	train-rmse:86280.7	test-rmse:87096.7
# [201]	train-rmse:86279.1	test-rmse:87095.7
# [202]	train-rmse:86275.7	test-rmse:87095.4
# [203]	train-rmse:86271.2	test-rmse:87093.5
# [204]	train-rmse:86270.7	test-rmse:87093.2
# [205]	train-rmse:86270	test-rmse:87093.1
# [206]	train-rmse:86267.3	test-rmse:87092.7
# [207]	train-rmse:86264.2	test-rmse:87092.5
# [208]	train-rmse:86263.6	test-rmse:87092.6
# [209]	train-rmse:86260.2	test-rmse:87091.8
# [210]	train-rmse:86258.2	test-rmse:87092.3
# [211]	train-rmse:86255.4	test-rmse:87091
# [212]	train-rmse:86250.7	test-rmse:87090.5
# [213]	train-rmse:86247.6	test-rmse:87088.7
# [214]	train-rmse:86245.1	test-rmse:87088.5
# [215]	train-rmse:86241	test-rmse:87087.7
# [216]	train-rmse:86239.1	test-rmse:87087.4
# [217]	train-rmse:86236.6	test-rmse:87087.7
# [218]	train-rmse:86234.4	test-rmse:87087.3
# [219]	train-rmse:86232.9	test-rmse:87087
# [220]	train-rmse:86229.9	test-rmse:87086.8
# [221]	train-rmse:86227	test-rmse:87086.8
# [222]	train-rmse:86226.6	test-rmse:87086.9
# [223]	train-rmse:86225.8	test-rmse:87087
# [224]	train-rmse:86222.8	test-rmse:87087
# [225]	train-rmse:86220.8	test-rmse:87086.9
# [226]	train-rmse:86217.7	test-rmse:87086.9
# [227]	train-rmse:86215.4	test-rmse:87087.4
# [228]	train-rmse:86211.6	test-rmse:87086.2
# [229]	train-rmse:86211.1	test-rmse:87086.1
# [230]	train-rmse:86210.2	test-rmse:87086
# [231]	train-rmse:86206.4	test-rmse:87085.1
# [232]	train-rmse:86203.6	test-rmse:87084.6
# [233]	train-rmse:86199.4	test-rmse:87083.7
# [234]	train-rmse:86194.7	test-rmse:87081.7
# [235]	train-rmse:86192.9	test-rmse:87081.8
# [236]	train-rmse:86190.1	test-rmse:87081.9
# [237]	train-rmse:86186.6	test-rmse:87080.9
# [238]	train-rmse:86181	test-rmse:87077.9
# [239]	train-rmse:86176.9	test-rmse:87076.3
# [240]	train-rmse:86173.9	test-rmse:87075.6
# [241]	train-rmse:86171.6	test-rmse:87075.6
# [242]	train-rmse:86169	test-rmse:87075.4
# [243]	train-rmse:86164.6	test-rmse:87074.3
# [244]	train-rmse:86163.5	test-rmse:87074.4
# [245]	train-rmse:86162.9	test-rmse:87074.4
# [246]	train-rmse:86159.6	test-rmse:87073.9
# [247]	train-rmse:86156.6	test-rmse:87073.6
# [248]	train-rmse:86156.2	test-rmse:87073.6
# [249]	train-rmse:86154.4	test-rmse:87073.8
# [250]	train-rmse:86153.6	test-rmse:87073.9
# [251]	train-rmse:86151	test-rmse:87073.8
# [252]	train-rmse:86147.5	test-rmse:87072.5
# [253]	train-rmse:86145.4	test-rmse:87072.4
# [254]	train-rmse:86144.9	test-rmse:87072.3
# [255]	train-rmse:86144.6	test-rmse:87072.3
# [256]	train-rmse:86140	test-rmse:87070.4
# [257]	train-rmse:86136.9	test-rmse:87070.2
# [258]	train-rmse:86133.9	test-rmse:87069.3
# [259]	train-rmse:86131.7	test-rmse:87069.8
# [260]	train-rmse:86128.7	test-rmse:87068.9
# [261]	train-rmse:86124.5	test-rmse:87068.9
# [262]	train-rmse:86123	test-rmse:87069
# [263]	train-rmse:86122.2	test-rmse:87068.6
# [264]	train-rmse:86120.5	test-rmse:87068.8
# [265]	train-rmse:86118.5	test-rmse:87068.3
# [266]	train-rmse:86117.2	test-rmse:87068.5
# [267]	train-rmse:86115.6	test-rmse:87068.3
# [268]	train-rmse:86114	test-rmse:87067.8
# [269]	train-rmse:86111.4	test-rmse:87067.3
# [270]	train-rmse:86110.1	test-rmse:87066.9
# [271]	train-rmse:86109.8	test-rmse:87067
# [272]	train-rmse:86109.4	test-rmse:87067.1
# [273]	train-rmse:86105.6	test-rmse:87066.4
# [274]	train-rmse:86101.9	test-rmse:87066.1
# [275]	train-rmse:86099	test-rmse:87065.7
# [276]	train-rmse:86096.7	test-rmse:87065.6
# [277]	train-rmse:86092.7	test-rmse:87064.3
# [278]	train-rmse:86088.9	test-rmse:87063.6
# [279]	train-rmse:86087.8	test-rmse:87063.5
# [280]	train-rmse:86084.1	test-rmse:87062.3
# [281]	train-rmse:86083.4	test-rmse:87062.3
# [282]	train-rmse:86080.6	test-rmse:87062.3
# [283]	train-rmse:86077.6	test-rmse:87062.4
# [284]	train-rmse:86074.6	test-rmse:87062.2
# [285]	train-rmse:86071	test-rmse:87061.6
# [286]	train-rmse:86068.8	test-rmse:87061.7
# [287]	train-rmse:86066.2	test-rmse:87060.7
# [288]	train-rmse:86063.2	test-rmse:87060.2
# [289]	train-rmse:86061.5	test-rmse:87060.4
# [290]	train-rmse:86059.8	test-rmse:87060.4
# [291]	train-rmse:86059.3	test-rmse:87060.4
# [292]	train-rmse:86056	test-rmse:87059.3
# [293]	train-rmse:86051.6	test-rmse:87058.3
# [294]	train-rmse:86050.7	test-rmse:87058.4
# [295]	train-rmse:86049.2	test-rmse:87058
# [296]	train-rmse:86047.5	test-rmse:87058.3
# [297]	train-rmse:86044.2	test-rmse:87057.2
# [298]	train-rmse:86041.2	test-rmse:87057.8
# [299]	train-rmse:86038	test-rmse:87057.9
# [300]	train-rmse:86035.6	test-rmse:87057
# [301]	train-rmse:86033	test-rmse:87057
# [302]	train-rmse:86030.9	test-rmse:87056.6
# [303]	train-rmse:86027.4	test-rmse:87056.1
# [304]	train-rmse:86025.4	test-rmse:87056.4
# [305]	train-rmse:86023.5	test-rmse:87056.2
# [306]	train-rmse:86020.9	test-rmse:87056.2
# [307]	train-rmse:86018.7	test-rmse:87055.7
# [308]	train-rmse:86017.3	test-rmse:87055.3
# [309]	train-rmse:86016.5	test-rmse:87055
# [310]	train-rmse:86015.2	test-rmse:87054.8
# [311]	train-rmse:86014.5	test-rmse:87054.7
# [312]	train-rmse:86013.3	test-rmse:87054.6
# [313]	train-rmse:86012	test-rmse:87054.7
# [314]	train-rmse:86009.6	test-rmse:87054.1
# [315]	train-rmse:86009.3	test-rmse:87054.2
# [316]	train-rmse:86007.1	test-rmse:87053.8
# [317]	train-rmse:86004.9	test-rmse:87053.7
# [318]	train-rmse:86002.9	test-rmse:87053.8
# [319]	train-rmse:86000.1	test-rmse:87053.1
# [320]	train-rmse:85997.6	test-rmse:87052.9
# [321]	train-rmse:85994.6	test-rmse:87053
# [322]	train-rmse:85991.8	test-rmse:87052.5
# [323]	train-rmse:85988.7	test-rmse:87051.8
# [324]	train-rmse:85986.5	test-rmse:87051.5
# [325]	train-rmse:85983.3	test-rmse:87050.6
# [326]	train-rmse:85980.6	test-rmse:87050.2
# [327]	train-rmse:85977.9	test-rmse:87049.8
# [328]	train-rmse:85976	test-rmse:87050.1
# [329]	train-rmse:85973.9	test-rmse:87050.3
# [330]	train-rmse:85970.9	test-rmse:87049.7
# [331]	train-rmse:85969.1	test-rmse:87049.4
# [332]	train-rmse:85966.2	test-rmse:87048.9
# [333]	train-rmse:85963.1	test-rmse:87048.5
# [334]	train-rmse:85961.9	test-rmse:87048.6
# [335]	train-rmse:85960.5	test-rmse:87048.8
# [336]	train-rmse:85957.9	test-rmse:87047.9
# [337]	train-rmse:85955.4	test-rmse:87047.4
# [338]	train-rmse:85952	test-rmse:87047.6
# [339]	train-rmse:85948.9	test-rmse:87047
# [340]	train-rmse:85947.1	test-rmse:87046.7
# [341]	train-rmse:85946.1	test-rmse:87046.7
# [342]	train-rmse:85943.4	test-rmse:87047
# [343]	train-rmse:85941.1	test-rmse:87046.4
# [344]	train-rmse:85938.2	test-rmse:87046.4
# [345]	train-rmse:85937.4	test-rmse:87046.1
# [346]	train-rmse:85936.4	test-rmse:87045.9
# [347]	train-rmse:85934.9	test-rmse:87046
# [348]	train-rmse:85931.8	test-rmse:87045.3
# [349]	train-rmse:85929.4	test-rmse:87044.7
# [350]	train-rmse:85928.2	test-rmse:87044.6
# [351]	train-rmse:85926.6	test-rmse:87044.7
# [352]	train-rmse:85924.6	test-rmse:87043.9
# [353]	train-rmse:85922.7	test-rmse:87043.3
# [354]	train-rmse:85921.4	test-rmse:87043.4
# [355]	train-rmse:85921	test-rmse:87043.3
# [356]	train-rmse:85919	test-rmse:87042.9
# [357]	train-rmse:85917.9	test-rmse:87042.8
# [358]	train-rmse:85915	test-rmse:87042.4
# [359]	train-rmse:85914.7	test-rmse:87042.4
# [360]	train-rmse:85911.7	test-rmse:87041.7
# [361]	train-rmse:85908.9	test-rmse:87041.3
# [362]	train-rmse:85906.8	test-rmse:87041
# [363]	train-rmse:85904.1	test-rmse:87040.7
# [364]	train-rmse:85901.5	test-rmse:87041
# [365]	train-rmse:85898.7	test-rmse:87041.2
# [366]	train-rmse:85896.5	test-rmse:87040.6
# [367]	train-rmse:85894.2	test-rmse:87040.1
# [368]	train-rmse:85890.8	test-rmse:87039.9
# [369]	train-rmse:85889.1	test-rmse:87039.7
# [370]	train-rmse:85886.4	test-rmse:87039.4
# [371]	train-rmse:85884	test-rmse:87039.2
# [372]	train-rmse:85882.7	test-rmse:87039.2
# [373]	train-rmse:85880.6	test-rmse:87039.3
# [374]	train-rmse:85879.6	test-rmse:87039.3
# [375]	train-rmse:85877.9	test-rmse:87039.5
# [376]	train-rmse:85877.6	test-rmse:87039.6
# [377]	train-rmse:85875.6	test-rmse:87039.6
# [378]	train-rmse:85874	test-rmse:87039.4
# [379]	train-rmse:85872.5	test-rmse:87039.5
# [380]	train-rmse:85870.7	test-rmse:87039.3
# [381]	train-rmse:85869.2	test-rmse:87039.3
# [382]	train-rmse:85866.9	test-rmse:87038.8
# [383]	train-rmse:85864.5	test-rmse:87038.1
# [384]	train-rmse:85862.8	test-rmse:87038.1
# [385]	train-rmse:85861.2	test-rmse:87038.2
# [386]	train-rmse:85859.8	test-rmse:87038
# [387]	train-rmse:85857.1	test-rmse:87038.3
# [388]	train-rmse:85855.4	test-rmse:87038.2
# [389]	train-rmse:85854.2	test-rmse:87038
# [390]	train-rmse:85851.5	test-rmse:87037.7
# [391]	train-rmse:85849.8	test-rmse:87037.7
# [392]	train-rmse:85849.4	test-rmse:87037.6
# [393]	train-rmse:85848.7	test-rmse:87037.4
# [394]	train-rmse:85847.4	test-rmse:87037.3
# [395]	train-rmse:85846.1	test-rmse:87036.8
# [396]	train-rmse:85843.1	test-rmse:87036.8
# [397]	train-rmse:85839.8	test-rmse:87036.8
# [398]	train-rmse:85839.5	test-rmse:87037
# [399]	train-rmse:85837.8	test-rmse:87037
# [400]	train-rmse:85837.5	test-rmse:87036.9
# [401]	train-rmse:85836	test-rmse:87036.9
# [402]	train-rmse:85834.6	test-rmse:87036.9
# [403]	train-rmse:85832.5	test-rmse:87036.8
# [404]	train-rmse:85831.8	test-rmse:87036.8
# [405]	train-rmse:85831.1	test-rmse:87036.9
# [406]	train-rmse:85830.2	test-rmse:87037
# [407]	train-rmse:85827.4	test-rmse:87036.3
# [408]	train-rmse:85824.6	test-rmse:87035.7
# [409]	train-rmse:85821.5	test-rmse:87035.2
# [410]	train-rmse:85819.3	test-rmse:87035.2
# [411]	train-rmse:85817.8	test-rmse:87034.8
# [412]	train-rmse:85815	test-rmse:87033.8
# [413]	train-rmse:85811.7	test-rmse:87033.3
# [414]	train-rmse:85809.5	test-rmse:87033.9
# [415]	train-rmse:85807	test-rmse:87033.2
# [416]	train-rmse:85804.8	test-rmse:87032.7
# [417]	train-rmse:85802.6	test-rmse:87032.9
# [418]	train-rmse:85800	test-rmse:87032.6
# [419]	train-rmse:85799.6	test-rmse:87032.6
# [420]	train-rmse:85797.1	test-rmse:87031.9
# [421]	train-rmse:85795.2	test-rmse:87032
# [422]	train-rmse:85794.4	test-rmse:87031.8
# [423]	train-rmse:85791.9	test-rmse:87031.1
# [424]	train-rmse:85790.7	test-rmse:87031.2
# [425]	train-rmse:85789.5	test-rmse:87031.4
# [426]	train-rmse:85788	test-rmse:87031.6
# [427]	train-rmse:85785.8	test-rmse:87031.6
# [428]	train-rmse:85783.6	test-rmse:87032
# [429]	train-rmse:85783.1	test-rmse:87031.9
# [430]	train-rmse:85780.7	test-rmse:87032
# [431]	train-rmse:85777.9	test-rmse:87032.3
# [432]	train-rmse:85775.4	test-rmse:87031.5
# [433]	train-rmse:85774.2	test-rmse:87031.8
# [434]	train-rmse:85771.6	test-rmse:87031.3
# [435]	train-rmse:85771.1	test-rmse:87031.4
# [436]	train-rmse:85766.8	test-rmse:87029.1
# [437]	train-rmse:85765.3	test-rmse:87029.4
# [438]	train-rmse:85762.9	test-rmse:87029.6
# [439]	train-rmse:85762.6	test-rmse:87029.7
# [440]	train-rmse:85761.7	test-rmse:87029.8
# [441]	train-rmse:85760.3	test-rmse:87029.8
# [442]	train-rmse:85758.8	test-rmse:87029.9
# [443]	train-rmse:85758.1	test-rmse:87029.9
# [444]	train-rmse:85756.4	test-rmse:87029.6
# [445]	train-rmse:85754.1	test-rmse:87029.3
# [446]	train-rmse:85752.4	test-rmse:87029.5
# [447]	train-rmse:85750.4	test-rmse:87030
# [448]	train-rmse:85748.5	test-rmse:87030.2
# [449]	train-rmse:85747.8	test-rmse:87030
# [450]	train-rmse:85747.4	test-rmse:87030
# [451]	train-rmse:85745	test-rmse:87029.3
# [452]	train-rmse:85742.3	test-rmse:87029.2
# [453]	train-rmse:85740.1	test-rmse:87029
# [454]	train-rmse:85737.8	test-rmse:87028.4
# [455]	train-rmse:85736.1	test-rmse:87028.8
# [456]	train-rmse:85734.3	test-rmse:87028.5
# [457]	train-rmse:85731.1	test-rmse:87027.2
# [458]	train-rmse:85729.5	test-rmse:87026.8
# [459]	train-rmse:85727.8	test-rmse:87026.8
# [460]	train-rmse:85726.4	test-rmse:87026.7
# [461]	train-rmse:85723.5	test-rmse:87026.6
# [462]	train-rmse:85722	test-rmse:87026.6
# [463]	train-rmse:85720.5	test-rmse:87026.6
# [464]	train-rmse:85719.6	test-rmse:87026.8
# [465]	train-rmse:85716.8	test-rmse:87026.7
# [466]	train-rmse:85714.7	test-rmse:87026.4
# [467]	train-rmse:85711.9	test-rmse:87026.2
# [468]	train-rmse:85710	test-rmse:87026
# [469]	train-rmse:85708.4	test-rmse:87026.1
# [470]	train-rmse:85706.5	test-rmse:87026
# [471]	train-rmse:85703.1	test-rmse:87025.8
# [472]	train-rmse:85701.4	test-rmse:87025.6
# [473]	train-rmse:85700.2	test-rmse:87025.5
# [474]	train-rmse:85699.4	test-rmse:87025.4
# [475]	train-rmse:85698.6	test-rmse:87025.2
# [476]	train-rmse:85697.2	test-rmse:87025.5
# [477]	train-rmse:85695	test-rmse:87025.3
# [478]	train-rmse:85693.3	test-rmse:87025.1
# [479]	train-rmse:85691.1	test-rmse:87024.9
# [480]	train-rmse:85689.3	test-rmse:87024.9
# [481]	train-rmse:85688.8	test-rmse:87025
# [482]	train-rmse:85687.4	test-rmse:87025
# [483]	train-rmse:85685.8	test-rmse:87024.8
# [484]	train-rmse:85684.2	test-rmse:87024.8
# [485]	train-rmse:85682.6	test-rmse:87024.8
# [486]	train-rmse:85682.3	test-rmse:87024.7
# [487]	train-rmse:85681.8	test-rmse:87025
# [488]	train-rmse:85679.3	test-rmse:87025.1
# [489]	train-rmse:85676.8	test-rmse:87024.2
# [490]	train-rmse:85675.6	test-rmse:87024.3
# [491]	train-rmse:85674.2	test-rmse:87024.6
# [492]	train-rmse:85671.4	test-rmse:87024.8
# [493]	train-rmse:85670.3	test-rmse:87024.9
# [494]	train-rmse:85667.9	test-rmse:87024.6
# [495]	train-rmse:85665.5	test-rmse:87024.3
# [496]	train-rmse:85663.8	test-rmse:87024.3
# [497]	train-rmse:85662.2	test-rmse:87024.4
# [498]	train-rmse:85661.9	test-rmse:87024.3
# [499]	train-rmse:85659.7	test-rmse:87023.6
# [500]	train-rmse:85658.6	test-rmse:87023.5
# [501]	train-rmse:85656.7	test-rmse:87023.7
# [502]	train-rmse:85654.5	test-rmse:87023.9
# [503]	train-rmse:85652.8	test-rmse:87023.7
# [504]	train-rmse:85651	test-rmse:87023.6
# [505]	train-rmse:85648.8	test-rmse:87023.7
# [506]	train-rmse:85647	test-rmse:87023.3
# [507]	train-rmse:85645.9	test-rmse:87023.1
# [508]	train-rmse:85644.1	test-rmse:87023.1
# [509]	train-rmse:85642.2	test-rmse:87022.7
# [510]	train-rmse:85641.3	test-rmse:87022.6
# [511]	train-rmse:85640	test-rmse:87022.7
# [512]	train-rmse:85637.9	test-rmse:87022.7
# [513]	train-rmse:85636.3	test-rmse:87022.4
# [514]	train-rmse:85633.9	test-rmse:87021.8
# [515]	train-rmse:85632.4	test-rmse:87022
# [516]	train-rmse:85630.5	test-rmse:87021.6
# [517]	train-rmse:85628.1	test-rmse:87021.5
# [518]	train-rmse:85625.3	test-rmse:87021.1
# [519]	train-rmse:85623.1	test-rmse:87021.1
# [520]	train-rmse:85622.2	test-rmse:87021.2
# [521]	train-rmse:85620.6	test-rmse:87020.8
# [522]	train-rmse:85618.6	test-rmse:87020.6
# [523]	train-rmse:85617.2	test-rmse:87020.5
# [524]	train-rmse:85614.5	test-rmse:87019.9
# [525]	train-rmse:85611.4	test-rmse:87019.2
# [526]	train-rmse:85610	test-rmse:87018.8
# [527]	train-rmse:85607.9	test-rmse:87018.5
# [528]	train-rmse:85605.4	test-rmse:87018.5
# [529]	train-rmse:85603.8	test-rmse:87018
# [530]	train-rmse:85603.6	test-rmse:87018.1
# [531]	train-rmse:85602.4	test-rmse:87017.8
# [532]	train-rmse:85602.1	test-rmse:87017.9
# [533]	train-rmse:85601.7	test-rmse:87017.9
# [534]	train-rmse:85600.1	test-rmse:87017.9
# [535]	train-rmse:85596.4	test-rmse:87017.7
# [536]	train-rmse:85594.8	test-rmse:87017.8
# [537]	train-rmse:85594	test-rmse:87017.7
# [538]	train-rmse:85592.1	test-rmse:87017.7
# [539]	train-rmse:85590.5	test-rmse:87017.7
# [540]	train-rmse:85588	test-rmse:87017.9
# [541]	train-rmse:85586.8	test-rmse:87017.4
# [542]	train-rmse:85586.2	test-rmse:87017.4
# [543]	train-rmse:85584.3	test-rmse:87016.9
# [544]	train-rmse:85584	test-rmse:87017.1
# [545]	train-rmse:85581.5	test-rmse:87016.8
# [546]	train-rmse:85581.2	test-rmse:87016.7
# [547]	train-rmse:85579.5	test-rmse:87016.5
# [548]	train-rmse:85576.9	test-rmse:87015.8
# [549]	train-rmse:85573.6	test-rmse:87015.4
# [550]	train-rmse:85571.9	test-rmse:87015.8
# [551]	train-rmse:85570.5	test-rmse:87015.3
# [552]	train-rmse:85569.3	test-rmse:87015.5
# [553]	train-rmse:85567.4	test-rmse:87015.3
# [554]	train-rmse:85566.1	test-rmse:87015.6
# [555]	train-rmse:85565	test-rmse:87015.5
# [556]	train-rmse:85563.1	test-rmse:87015.1
# [557]	train-rmse:85560	test-rmse:87014.2
# [558]	train-rmse:85557.6	test-rmse:87014.2
# [559]	train-rmse:85555.4	test-rmse:87014.2
# [560]	train-rmse:85553.8	test-rmse:87014.1
# [561]	train-rmse:85551.7	test-rmse:87014
# [562]	train-rmse:85550.6	test-rmse:87013.5
# [563]	train-rmse:85549.3	test-rmse:87013.6
# [564]	train-rmse:85548.6	test-rmse:87013.7
# [565]	train-rmse:85546.4	test-rmse:87013.7
# [566]	train-rmse:85545.4	test-rmse:87014.1
# [567]	train-rmse:85544.7	test-rmse:87014
# [568]	train-rmse:85541.9	test-rmse:87013.5
# [569]	train-rmse:85539.7	test-rmse:87013
# [570]	train-rmse:85537.4	test-rmse:87012.9
# [571]	train-rmse:85535.4	test-rmse:87012.6
# [572]	train-rmse:85534.8	test-rmse:87012.8
# [573]	train-rmse:85532.8	test-rmse:87013.1
# [574]	train-rmse:85530.6	test-rmse:87012.9
# [575]	train-rmse:85528.7	test-rmse:87013.1
# [576]	train-rmse:85526.6	test-rmse:87012.7
# [577]	train-rmse:85524.5	test-rmse:87012.5
# [578]	train-rmse:85522.1	test-rmse:87012.7
# [579]	train-rmse:85520.2	test-rmse:87012.2
# [580]	train-rmse:85518.9	test-rmse:87012.2
# [581]	train-rmse:85516.4	test-rmse:87011.3
# [582]	train-rmse:85513.8	test-rmse:87010.9
# [583]	train-rmse:85512.1	test-rmse:87010.4
# [584]	train-rmse:85510	test-rmse:87010.6
# [585]	train-rmse:85507.9	test-rmse:87010.6
# [586]	train-rmse:85505.7	test-rmse:87010.4
# [587]	train-rmse:85502.4	test-rmse:87010.7
# [588]	train-rmse:85499.9	test-rmse:87010.8
# [589]	train-rmse:85496.7	test-rmse:87010.5
# [590]	train-rmse:85494.9	test-rmse:87010.4
# [591]	train-rmse:85492.9	test-rmse:87010.2
# [592]	train-rmse:85491.1	test-rmse:87010
# [593]	train-rmse:85488.6	test-rmse:87009.9
# [594]	train-rmse:85486.5	test-rmse:87009.8
# [595]	train-rmse:85484.5	test-rmse:87009.4
# [596]	train-rmse:85481.1	test-rmse:87008.7
# [597]	train-rmse:85479.3	test-rmse:87008.9
# [598]	train-rmse:85477.9	test-rmse:87008.6
# [599]	train-rmse:85476.9	test-rmse:87008.8
# [600]	train-rmse:85474.8	test-rmse:87008.4
# [601]	train-rmse:85473.8	test-rmse:87008.7
# [602]	train-rmse:85471.3	test-rmse:87008.2
# [603]	train-rmse:85469.2	test-rmse:87008.3
# [604]	train-rmse:85466.5	test-rmse:87008
# [605]	train-rmse:85464.2	test-rmse:87008.5
# [606]	train-rmse:85462	test-rmse:87008.3
# [607]	train-rmse:85460.7	test-rmse:87008.6
# [608]	train-rmse:85457.7	test-rmse:87008
# [609]	train-rmse:85455.2	test-rmse:87007.2
# [610]	train-rmse:85452.5	test-rmse:87006.9
# [611]	train-rmse:85451.3	test-rmse:87007.1
# [612]	train-rmse:85448.2	test-rmse:87006.7
# [613]	train-rmse:85447.2	test-rmse:87006.7
# [614]	train-rmse:85446.2	test-rmse:87006.5
# [615]	train-rmse:85445.1	test-rmse:87006.3
# [616]	train-rmse:85444.2	test-rmse:87006.3
# [617]	train-rmse:85442.4	test-rmse:87007.1
# [618]	train-rmse:85441.4	test-rmse:87007.2
# [619]	train-rmse:85441	test-rmse:87007
# [620]	train-rmse:85439.4	test-rmse:87006.2
# [621]	train-rmse:85437.8	test-rmse:87006.2
# [622]	train-rmse:85435.4	test-rmse:87005.8
# [623]	train-rmse:85434.7	test-rmse:87005.8
# [624]	train-rmse:85434.5	test-rmse:87005.9
# [625]	train-rmse:85434.2	test-rmse:87006.1
# [626]	train-rmse:85432.5	test-rmse:87005.4
# [627]	train-rmse:85430.6	test-rmse:87004.8
# [628]	train-rmse:85427.6	test-rmse:87004.7
# [629]	train-rmse:85424.7	test-rmse:87005.1
# [630]	train-rmse:85423.9	test-rmse:87005.3
# [631]	train-rmse:85421.7	test-rmse:87005.5
# [632]	train-rmse:85420.6	test-rmse:87005.7
# [633]	train-rmse:85418.6	test-rmse:87005.3
# [634]	train-rmse:85417.5	test-rmse:87005.4
# [635]	train-rmse:85416	test-rmse:87005.3
# [636]	train-rmse:85414.5	test-rmse:87005
# [637]	train-rmse:85412.6	test-rmse:87005.5
# [638]	train-rmse:85410.6	test-rmse:87005.9
# [639]	train-rmse:85408.5	test-rmse:87005.9
# [640]	train-rmse:85406.6	test-rmse:87005.7
# [641]	train-rmse:85404.5	test-rmse:87005.6
# [642]	train-rmse:85402.7	test-rmse:87005.9
# [643]	train-rmse:85399.2	test-rmse:87005.4
# [644]	train-rmse:85398	test-rmse:87005.4
# [645]	train-rmse:85395.3	test-rmse:87004.9
# [646]	train-rmse:85393.1	test-rmse:87005.2
# [647]	train-rmse:85391.8	test-rmse:87005.3
# [648]	train-rmse:85391.1	test-rmse:87005.1
# Stopping. Best iteration:
# [628]	train-rmse:85427.6	test-rmse:87004.7

# %% [markdown]
# ### Evaluacion de modelos

# %% [markdown]
# preds_auctions1 = model1.predict(X_test_auctions)
# error_cuadrado_suma_auctions = ((preds_auctions1 - y_test_auctions)**2).sum()
#
# preds_installs1 = model1.predict(X_test_installs)

# %% [markdown]
# ## Pruebas con features reducidos

# %% [markdown]
# #### Datos con ventanas de 4 dias, los features de auctions se mantienen, cambian los de events clicks e installs dejando pocos de cada uno

# %%
train = pd.read_pickle("../../armado_datos/train_nuevo_completo")

# %%
(train["target"] == 259200.0).sum() / len(train)
# Out:
# 0.28187048468905734

# %%
train_maximos = train[train["target"] == train["target"].max()]

# %%
len(train_maximos)
# Out:
# 362497

# %% [markdown]
# #### DIferentes nombres de datasets con los que probé:
#
# ##### __train__ : Dataset completo
#
# ##### __train_red__ : Me quede con todos los que tenian valores maximos y agrege una muestra random de 400 mil de las que tenian valor antes de los 3 dias, la prueba no dio bien, igual que siempre
#
# ##### __train_disminuido__ : Dataset filtrado con distintos valores pidiendo cierta cantidad de nulos, el que más mejora dependiendo el valor elegidoDistintos valores con los que fui jugando para filtrar

# %%
train_red = train[~(train["target"] == train["target"].max())].sample(400000,random_state = 1)

# %%
train_red = train_red.append(train_maximos)

# %%
train_red.fillna(0,inplace = True)

# %% [markdown]
# ---

# %% [markdown]
# #### Quedarme con los que tienen menos datos vacios de events, installs y clicks

# %%
cantidad_columnas = len(train.columns) - 1

# %%
train.fillna(0,inplace = True)

# %%
train["cant_nulos"] = train.apply(lambda x: cantidad_columnas - (np.count_nonzero((x.to_numpy()))) ,axis = 1)

# %%
cantidad_columnas
# Out:
# 57

# %%
train["cant_nulos"].max()
# Out:
# 48

# %%
len(train)
# Out:
# 1286041

# %%
train["cant_nulos"].value_counts().head(10)
# Out:
# 46    126119
# 40     96885
# 42     96551
# 41     95111
# 39     93945
# 43     88216
# 38     84699
# 37     75023
# 36     66030
# 35     56705
# Name: cant_nulos, dtype: int64

# %%
len(train[train["cant_nulos"] < 38])
# Out:
# 525807

# %%
train_disminuido = train[train["cant_nulos"] < 38]

# %% [markdown]
# ## Porcentaje de valores maximos dentro de lo disminuido

# %%
len(train_disminuido[train_disminuido["target"] == train["target"].max()]) / len(train_disminuido) * 100
# Out:
# 11.755263813528538

# %% [markdown]
# ---

# %% [markdown]
# ### Prueba:
# #### Los resultados de cada prueba estan anotados como comentario

# %%
X, y = train_disminuido.drop("target",axis = 1), train_disminuido["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)

#reducido 
#Stopping. Best iteration:
#[317]	train-rmse:88534.2	test-rmse:89883.8


#Completo sin rellenar los nan con 0
#Stopping. Best iteration:
#[598]	train-rmse:87166.5	test-rmse:88788


#Filtrado por cantidad de 0 menor a 42 sobre maximo de 48
#len 896 mil 
#Stopping. Best iteration:
#[306]	train-rmse:84055.4	test-rmse:85194.5


#Filtrados menor a 40
#len 704 mil
#[323]	train-rmse:79957.7	test-rmse:81724.4


#Filtrados a menor de 41
#len 801 mil
#[404]	train-rmse:81918.7	test-rmse:83678.8


#Filtrados menor a 39
#len 610 mil
#[267]	train-rmse:77538.2	test-rmse:79137.7

#Filtrados menor a 38
#len 525 mil
#[217]	train-rmse:74849	test-rmse:76739.9
# Out:
# [0]	train-rmse:107314	test-rmse:107847
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:102361	test-rmse:102884
# [2]	train-rmse:98161.9	test-rmse:98668.9
# [3]	train-rmse:94855.1	test-rmse:95359.6
# [4]	train-rmse:91804.3	test-rmse:92296.6
# [5]	train-rmse:89240.2	test-rmse:89729.1
# [6]	train-rmse:87112.4	test-rmse:87597.8
# [7]	train-rmse:85341.5	test-rmse:85820.3
# [8]	train-rmse:83851.1	test-rmse:84325.1
# [9]	train-rmse:82621.7	test-rmse:83099.1
# [10]	train-rmse:81597.4	test-rmse:82067.9
# [11]	train-rmse:80751.4	test-rmse:81226.3
# [12]	train-rmse:80051	test-rmse:80529.3
# [13]	train-rmse:79480.2	test-rmse:79963.7
# [14]	train-rmse:78998.1	test-rmse:79486.9
# [15]	train-rmse:78601.4	test-rmse:79094.5
# [16]	train-rmse:78264.1	test-rmse:78762.7
# [17]	train-rmse:77976.2	test-rmse:78482.8
# [18]	train-rmse:77742.4	test-rmse:78258.9
# [19]	train-rmse:77565.5	test-rmse:78093.5
# [20]	train-rmse:77395.9	test-rmse:77931.4
# [21]	train-rmse:77251.5	test-rmse:77792.9
# [22]	train-rmse:77133.1	test-rmse:77680.2
# [23]	train-rmse:77027.1	test-rmse:77579.6
# [24]	train-rmse:76935.4	test-rmse:77497.3
# [25]	train-rmse:76860.2	test-rmse:77430.2
# [26]	train-rmse:76791.9	test-rmse:77372.8
# [27]	train-rmse:76732.8	test-rmse:77322.4
# [28]	train-rmse:76680	test-rmse:77281.3
# [29]	train-rmse:76632.9	test-rmse:77246
# [30]	train-rmse:76590.1	test-rmse:77208.2
# [31]	train-rmse:76550.5	test-rmse:77179.6
# [32]	train-rmse:76515.2	test-rmse:77151.9
# [33]	train-rmse:76475.5	test-rmse:77122.6
# [34]	train-rmse:76446.3	test-rmse:77103.8
# [35]	train-rmse:76413.2	test-rmse:77080.4
# [36]	train-rmse:76384.7	test-rmse:77060
# [37]	train-rmse:76356.9	test-rmse:77040.8
# [38]	train-rmse:76333.6	test-rmse:77024.7
# [39]	train-rmse:76312.6	test-rmse:77014.2
# [40]	train-rmse:76288.2	test-rmse:77001.4
# [41]	train-rmse:76269.1	test-rmse:76989.6
# [42]	train-rmse:76249.5	test-rmse:76978.3
# [43]	train-rmse:76230.8	test-rmse:76971.1
# [44]	train-rmse:76212.1	test-rmse:76960.8
# [45]	train-rmse:76195.2	test-rmse:76954.2
# [46]	train-rmse:76181.8	test-rmse:76948.3
# [47]	train-rmse:76164.9	test-rmse:76940.8
# [48]	train-rmse:76150.9	test-rmse:76935.7
# [49]	train-rmse:76137.3	test-rmse:76932.7
# [50]	train-rmse:76120.9	test-rmse:76928.2
# [51]	train-rmse:76100.9	test-rmse:76919
# [52]	train-rmse:76088.2	test-rmse:76913.9
# [53]	train-rmse:76073.6	test-rmse:76907.2
# [54]	train-rmse:76059.5	test-rmse:76901.8
# [55]	train-rmse:76046.9	test-rmse:76897.1
# [56]	train-rmse:76032.1	test-rmse:76891.5
# [57]	train-rmse:76017.6	test-rmse:76887.9
# [58]	train-rmse:76004.9	test-rmse:76885.9
# [59]	train-rmse:75995.3	test-rmse:76881.5
# [60]	train-rmse:75978.4	test-rmse:76873
# [61]	train-rmse:75962	test-rmse:76867.8
# [62]	train-rmse:75950.7	test-rmse:76865
# [63]	train-rmse:75937.8	test-rmse:76860.5
# [64]	train-rmse:75924.7	test-rmse:76855.8
# [65]	train-rmse:75915.3	test-rmse:76852
# [66]	train-rmse:75902.9	test-rmse:76848.5
# [67]	train-rmse:75893.3	test-rmse:76847.5
# [68]	train-rmse:75885.4	test-rmse:76847.2
# [69]	train-rmse:75873.3	test-rmse:76845.2
# [70]	train-rmse:75862.3	test-rmse:76842.6
# [71]	train-rmse:75849.6	test-rmse:76838.5
# [72]	train-rmse:75838.7	test-rmse:76836.9
# [73]	train-rmse:75824.8	test-rmse:76833.1
# [74]	train-rmse:75816.6	test-rmse:76828.7
# [75]	train-rmse:75810.1	test-rmse:76827.1
# [76]	train-rmse:75800.6	test-rmse:76823.6
# [77]	train-rmse:75786.7	test-rmse:76820.9
# [78]	train-rmse:75778.3	test-rmse:76820.5
# [79]	train-rmse:75770	test-rmse:76817.8
# [80]	train-rmse:75762.5	test-rmse:76815
# [81]	train-rmse:75751.7	test-rmse:76813.3
# [82]	train-rmse:75741.7	test-rmse:76812
# [83]	train-rmse:75732.9	test-rmse:76810.4
# [84]	train-rmse:75725.2	test-rmse:76808.9
# [85]	train-rmse:75715.9	test-rmse:76806.6
# [86]	train-rmse:75703.6	test-rmse:76804.2
# [87]	train-rmse:75697.2	test-rmse:76802.7
# [88]	train-rmse:75692.8	test-rmse:76801.4
# [89]	train-rmse:75686.5	test-rmse:76800.7
# [90]	train-rmse:75677.4	test-rmse:76797.8
# [91]	train-rmse:75666.7	test-rmse:76795.9
# [92]	train-rmse:75662.6	test-rmse:76796.2
# [93]	train-rmse:75653.9	test-rmse:76794.9
# [94]	train-rmse:75646.7	test-rmse:76795.2
# [95]	train-rmse:75636.1	test-rmse:76793.2
# [96]	train-rmse:75633.2	test-rmse:76792.6
# [97]	train-rmse:75628.6	test-rmse:76793.6
# [98]	train-rmse:75615.1	test-rmse:76789.9
# [99]	train-rmse:75607.7	test-rmse:76788.4
# [100]	train-rmse:75602.3	test-rmse:76788.3
# [101]	train-rmse:75594.1	test-rmse:76787.9
# [102]	train-rmse:75583.9	test-rmse:76788.1
# [103]	train-rmse:75577	test-rmse:76789
# [104]	train-rmse:75573	test-rmse:76789.2
# [105]	train-rmse:75568.1	test-rmse:76788.8
# [106]	train-rmse:75560.5	test-rmse:76787.4
# [107]	train-rmse:75555.5	test-rmse:76787.8
# [108]	train-rmse:75549.3	test-rmse:76787.8
# [109]	train-rmse:75544.4	test-rmse:76786.8
# [110]	train-rmse:75534.2	test-rmse:76787.1
# [111]	train-rmse:75524.3	test-rmse:76785.5
# [112]	train-rmse:75513.8	test-rmse:76787.1
# [113]	train-rmse:75502.2	test-rmse:76784.4
# [114]	train-rmse:75493.3	test-rmse:76783.5
# [115]	train-rmse:75489.3	test-rmse:76783.1
# [116]	train-rmse:75483.4	test-rmse:76782.3
# [117]	train-rmse:75474.7	test-rmse:76780.3
# [118]	train-rmse:75465.7	test-rmse:76780
# [119]	train-rmse:75453.9	test-rmse:76776.8
# [120]	train-rmse:75446.3	test-rmse:76775.8
# [121]	train-rmse:75440.2	test-rmse:76775.8
# [122]	train-rmse:75437.4	test-rmse:76775.7
# [123]	train-rmse:75432.4	test-rmse:76775.2
# [124]	train-rmse:75430.6	test-rmse:76775
# [125]	train-rmse:75423.6	test-rmse:76775.5
# [126]	train-rmse:75416.8	test-rmse:76773.7
# [127]	train-rmse:75411.2	test-rmse:76773.2
# [128]	train-rmse:75403.8	test-rmse:76773.6
# [129]	train-rmse:75397.2	test-rmse:76773.8
# [130]	train-rmse:75388.6	test-rmse:76772.6
# [131]	train-rmse:75379.6	test-rmse:76770.1
# [132]	train-rmse:75375.6	test-rmse:76770.3
# [133]	train-rmse:75371.7	test-rmse:76769.6
# [134]	train-rmse:75364.3	test-rmse:76768.3
# [135]	train-rmse:75362.9	test-rmse:76768.8
# [136]	train-rmse:75357.9	test-rmse:76767.1
# [137]	train-rmse:75350.4	test-rmse:76766.8
# [138]	train-rmse:75346.3	test-rmse:76767.3
# [139]	train-rmse:75339.4	test-rmse:76766.2
# [140]	train-rmse:75331.7	test-rmse:76764.9
# [141]	train-rmse:75323	test-rmse:76764.2
# [142]	train-rmse:75314.3	test-rmse:76761.8
# [143]	train-rmse:75309.4	test-rmse:76762.4
# [144]	train-rmse:75300.9	test-rmse:76761
# [145]	train-rmse:75291.7	test-rmse:76759.9
# [146]	train-rmse:75284.4	test-rmse:76760
# [147]	train-rmse:75281.6	test-rmse:76761.3
# [148]	train-rmse:75277.3	test-rmse:76759.6
# [149]	train-rmse:75266.6	test-rmse:76758.1
# [150]	train-rmse:75255.8	test-rmse:76754.3
# [151]	train-rmse:75249.7	test-rmse:76755.1
# [152]	train-rmse:75244.5	test-rmse:76755.7
# [153]	train-rmse:75234.3	test-rmse:76754.9
# [154]	train-rmse:75226.7	test-rmse:76756
# [155]	train-rmse:75222.2	test-rmse:76755.3
# [156]	train-rmse:75217.4	test-rmse:76756.6
# [157]	train-rmse:75214.1	test-rmse:76756.8
# [158]	train-rmse:75208.5	test-rmse:76755.7
# [159]	train-rmse:75202.9	test-rmse:76756.8
# [160]	train-rmse:75196.2	test-rmse:76756.8
# [161]	train-rmse:75186.5	test-rmse:76758.4
# [162]	train-rmse:75178.4	test-rmse:76757.8
# [163]	train-rmse:75172.7	test-rmse:76757
# [164]	train-rmse:75168	test-rmse:76756.8
# [165]	train-rmse:75161.6	test-rmse:76755.9
# [166]	train-rmse:75155.9	test-rmse:76756.2
# [167]	train-rmse:75148.7	test-rmse:76754.8
# [168]	train-rmse:75147.3	test-rmse:76755.1
# [169]	train-rmse:75140.9	test-rmse:76754.6
# [170]	train-rmse:75131	test-rmse:76752.3
# [171]	train-rmse:75125.6	test-rmse:76751.2
# [172]	train-rmse:75119.2	test-rmse:76750.1
# [173]	train-rmse:75116.5	test-rmse:76750.4
# [174]	train-rmse:75109.7	test-rmse:76749.4
# [175]	train-rmse:75107.1	test-rmse:76749.4
# [176]	train-rmse:75100.5	test-rmse:76749.4
# [177]	train-rmse:75092.8	test-rmse:76748.3
# [178]	train-rmse:75087.3	test-rmse:76748.7
# [179]	train-rmse:75082.2	test-rmse:76748.4
# [180]	train-rmse:75075.1	test-rmse:76748.8
# [181]	train-rmse:75068.8	test-rmse:76747.7
# [182]	train-rmse:75064.8	test-rmse:76748.9
# [183]	train-rmse:75055.7	test-rmse:76748.3
# [184]	train-rmse:75051.1	test-rmse:76747.5
# [185]	train-rmse:75041.3	test-rmse:76747.7
# [186]	train-rmse:75032.9	test-rmse:76747.9
# [187]	train-rmse:75026	test-rmse:76748.3
# [188]	train-rmse:75022.1	test-rmse:76747.7
# [189]	train-rmse:75018.3	test-rmse:76747
# [190]	train-rmse:75010.7	test-rmse:76745.7
# [191]	train-rmse:75003.8	test-rmse:76745.8
# [192]	train-rmse:74998.3	test-rmse:76744.8
# [193]	train-rmse:74993.7	test-rmse:76743.9
# [194]	train-rmse:74987.1	test-rmse:76744.4
# [195]	train-rmse:74980.4	test-rmse:76742.5
# [196]	train-rmse:74968.9	test-rmse:76743.9
# [197]	train-rmse:74960.5	test-rmse:76745.7
# [198]	train-rmse:74952.4	test-rmse:76744.6
# [199]	train-rmse:74946.3	test-rmse:76744.7
# [200]	train-rmse:74940.7	test-rmse:76745.7
# [201]	train-rmse:74939.3	test-rmse:76745.8
# [202]	train-rmse:74930	test-rmse:76744
# [203]	train-rmse:74923	test-rmse:76743.8
# [204]	train-rmse:74917.5	test-rmse:76745
# [205]	train-rmse:74912.7	test-rmse:76745.6
# [206]	train-rmse:74910.4	test-rmse:76744.9
# [207]	train-rmse:74906	test-rmse:76744.7
# [208]	train-rmse:74900.3	test-rmse:76743.4
# [209]	train-rmse:74894.5	test-rmse:76742.5
# [210]	train-rmse:74886.8	test-rmse:76742.2
# [211]	train-rmse:74884	test-rmse:76742
# [212]	train-rmse:74877.2	test-rmse:76742.3
# [213]	train-rmse:74871.2	test-rmse:76741.1
# [214]	train-rmse:74864.7	test-rmse:76742.7
# [215]	train-rmse:74862.1	test-rmse:76743
# [216]	train-rmse:74856.1	test-rmse:76742.8
# [217]	train-rmse:74849	test-rmse:76739.9
# [218]	train-rmse:74840.8	test-rmse:76741.4
# [219]	train-rmse:74839.1	test-rmse:76741.1
# [220]	train-rmse:74837	test-rmse:76741.4
# [221]	train-rmse:74835.4	test-rmse:76741.7
# [222]	train-rmse:74828.5	test-rmse:76741.2
# [223]	train-rmse:74822.8	test-rmse:76741.4
# [224]	train-rmse:74819.4	test-rmse:76742.7
# [225]	train-rmse:74813	test-rmse:76743.2
# [226]	train-rmse:74810.5	test-rmse:76742.3
# [227]	train-rmse:74809.4	test-rmse:76742.6
# [228]	train-rmse:74807.3	test-rmse:76743.1
# [229]	train-rmse:74799.3	test-rmse:76742.6
# [230]	train-rmse:74792.8	test-rmse:76742.1
# [231]	train-rmse:74785.2	test-rmse:76742.9
# [232]	train-rmse:74778.9	test-rmse:76744.1
# [233]	train-rmse:74771.2	test-rmse:76742.9
# [234]	train-rmse:74762.3	test-rmse:76742.5
# [235]	train-rmse:74752.3	test-rmse:76742.7
# [236]	train-rmse:74745.5	test-rmse:76743.7
# [237]	train-rmse:74741.2	test-rmse:76744.4
# Stopping. Best iteration:
# [217]	train-rmse:74849	test-rmse:76739.9

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Prueba de todos los datos para auctions y con outer join (EXPLOTA)

# %%
train = pd.read_pickle("../../armado_datos/train_completo_auctions_outer")

# %%
len(train)
# Out:
# 1734598

# %%
X, y = train.drop("target",axis = 1), train["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)

# Datos completos
#[114]	train-rmse:56684.6	test-rmse:57113
#Stopping. Best iteration:
#[94]	train-rmse:56717.6	test-rmse:57109.4
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:nan	test-rmse:nan
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:nan	test-rmse:nan
# [2]	train-rmse:nan	test-rmse:nan
# [3]	train-rmse:nan	test-rmse:nan
# [4]	train-rmse:nan	test-rmse:nan
# [5]	train-rmse:nan	test-rmse:nan
# [6]	train-rmse:nan	test-rmse:nan
# [7]	train-rmse:nan	test-rmse:nan
# [8]	train-rmse:nan	test-rmse:nan
# [9]	train-rmse:nan	test-rmse:nan
# [10]	train-rmse:nan	test-rmse:nan
# [11]	train-rmse:nan	test-rmse:nan
# [12]	train-rmse:nan	test-rmse:nan
# [13]	train-rmse:nan	test-rmse:nan
# [14]	train-rmse:nan	test-rmse:nan
# [15]	train-rmse:nan	test-rmse:nan
# [16]	train-rmse:nan	test-rmse:nan
# [17]	train-rmse:nan	test-rmse:nan
# [18]	train-rmse:nan	test-rmse:nan
# [19]	train-rmse:nan	test-rmse:nan
# [20]	train-rmse:nan	test-rmse:nan
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-7edbf6df0ec1> in <module>
#      23 num_round = 5000
#      24 stopping = 20
# ---> 25 bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)
#      26
#      27 # Datos completos
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      97                                end_iteration=num_boost_round,
#      98                                rank=rank,
# ---> 99                                evaluation_result_list=evaluation_result_list))
#     100         except EarlyStopException:
#     101             break
#
# ~/anaconda3/lib/python3.6/site-packages/xgboost/callback.py in callback(env)
#     243                                    best_msg=state['best_msg'])
#     244         elif env.iteration - best_iteration >= stopping_rounds:
# --> 245             best_msg = state['best_msg']
#     246             if verbose and env.rank == 0:
#     247                 msg = "Stopping. Best iteration:\n{}\n\n"
#
# KeyError: 'best_msg'

# %% [markdown]
# ---

# %% [markdown]
# ## Prueba de PCA (No mejoró)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
train = pd.read_pickle("../../armado_datos/train_nuevo_completo")

# %%
target = train["target"]

# %%
train.fillna(0,inplace = True)

# %%
train.drop("target",axis =1,inplace = True)

# %%
len(train.columns)
# Out:
# 57

# %%
sc = StandardScaler()
train_red = sc.fit_transform(train)

# %%
pca = PCA()

# %%
train_red = pca.fit_transform(train_red)

# %%
explained_variance = pca.explained_variance_ratio_

# %%
len(explained_variance)
# Out:
# 57

# %%
datos = np.cumsum(explained_variance)
#maximo = datos.max()

plt.figure(figsize = (13,6))
plt.plot(datos)
#plt.plot(maximo,marker = "o")
plt.xlabel("Numero de componentes")
plt.ylabel("Varianza %")
#plt.xticks(np.arange(47))

plt.title("Varianza del conjunto de datos")
# Out:
# Text(0.5, 1.0, 'Varianza del conjunto de datos')

# %%
pd.DataFrame(datos).tail(12)
# Out:
#            0
# 45  0.961580
# 46  0.968124
# 47  0.974540
# 48  0.980678
# 49  0.986535
# 50  0.991887
# 51  0.997093
# 52  1.000000
# 53  1.000000
# 54  1.000000
# 55  1.000000
# 56  1.000000

# %%
dimensiones = 51

# %%
train_red = sc.fit_transform(train)

# %%
pca = PCA(n_components = dimensiones)

# %%
train_red = pca.fit_transform(train_red)

# %%
train_red = pd.DataFrame(train_red)

# %%
train_red.set_index(train.index,inplace = True)

# %%
train_red["target"] = target

# %%
train_red.head()
# Out:
#                              0         1         2         3         4  \
# device_id
# 1826643666390887030   3.029708 -0.952875 -0.900757 -0.570948 -1.214764
# 7037174172278258682   7.368170 -1.614197 -1.610243 -1.873666 -1.169123
# 3392065368947589877  12.883611  1.979601  3.743669  0.928535 -4.169302
# 1228982273563226229  38.125136 -7.504183 -9.983208 -9.642790 -9.569863
# 4123059034628125459  -0.883740  0.800245  0.548252 -0.966809  1.575581
#
#                             5         6         7         8         9  ...  \
# device_id                                                              ...
# 1826643666390887030 -1.880975  0.754442 -0.017549  2.164250 -0.178239  ...
# 7037174172278258682 -0.422430  2.073419 -0.763951  1.549227 -0.520047  ...
# 3392065368947589877 -3.285090 -2.707817  2.212245  1.927350 -0.609984  ...
# 1228982273563226229  0.564173 -1.671473 -1.102302 -1.793512 -2.168370  ...
# 4123059034628125459 -1.908438 -0.222116  0.110548 -0.125854 -2.224515  ...
#
#                            42        43        44        45        46  \
# device_id
# 1826643666390887030 -0.410869  0.886306 -3.668756 -1.055747  1.068537
# 7037174172278258682  0.665803  0.574586  1.094853 -0.082026 -0.503823
# 3392065368947589877 -1.868608 -0.983807  1.198628  0.031857  1.019880
# 1228982273563226229 -5.615650  1.688741 -0.183203 -0.159803 -6.248659
# 4123059034628125459 -0.162291  0.105687 -0.100333  0.024281 -0.007887
#
#                            47        48        49        50         target
# device_id
# 1826643666390887030 -0.881789  0.389737  0.013890  1.006452   75658.343525
# 7037174172278258682 -1.733438  1.403036  0.793636  0.248385     135.824498
# 3392065368947589877  1.424889 -1.354964  0.481607  1.132388  234266.865041
# 1228982273563226229  0.099539 -3.964393 -0.492863 -2.652984    2363.081608
# 4123059034628125459 -0.011536  0.093561  0.016502  0.094006  147350.860399
#
# [5 rows x 52 columns]

# %% [markdown]
# #### Prueba

# %%
X, y = train_red.drop("target",axis = 1), train_red["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 20
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)


# Reducido con PCA 51 dimensiones completo
#
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:148868	test-rmse:148810
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 20 rounds.
# [1]	train-rmse:139936	test-rmse:139904
# [2]	train-rmse:132136	test-rmse:132135
# [3]	train-rmse:125497	test-rmse:125533
# [4]	train-rmse:119869	test-rmse:119911
# [5]	train-rmse:114998	test-rmse:115058
# [6]	train-rmse:110860	test-rmse:110951
# [7]	train-rmse:107391	test-rmse:107504
# [8]	train-rmse:104476	test-rmse:104611
# [9]	train-rmse:102093	test-rmse:102253
# [10]	train-rmse:100059	test-rmse:100239
# [11]	train-rmse:98352.9	test-rmse:98555
# [12]	train-rmse:96950	test-rmse:97169.8
# [13]	train-rmse:95797	test-rmse:96035.8
# [14]	train-rmse:94872.6	test-rmse:95127.1
# [15]	train-rmse:94062.1	test-rmse:94330.3
# [16]	train-rmse:93392.6	test-rmse:93676.9
# [17]	train-rmse:92843.5	test-rmse:93137.9
# [18]	train-rmse:92400.9	test-rmse:92708.6
# [19]	train-rmse:92023.7	test-rmse:92342.7
# [20]	train-rmse:91699.7	test-rmse:92026.7
# [21]	train-rmse:91442.1	test-rmse:91779.9
# [22]	train-rmse:91219.2	test-rmse:91564.7
# [23]	train-rmse:91029.7	test-rmse:91384.2
# [24]	train-rmse:90884.2	test-rmse:91246.7
# [25]	train-rmse:90769.3	test-rmse:91138.4
# [26]	train-rmse:90660.6	test-rmse:91034.4
# [27]	train-rmse:90558.4	test-rmse:90941.3
# [28]	train-rmse:90472.5	test-rmse:90864.8
# [29]	train-rmse:90408.6	test-rmse:90805.9
# [30]	train-rmse:90343.9	test-rmse:90747.9
# [31]	train-rmse:90287.7	test-rmse:90698.4
# [32]	train-rmse:90238.9	test-rmse:90656.2
# [33]	train-rmse:90194	test-rmse:90619.2
# [34]	train-rmse:90153.1	test-rmse:90583.9
# [35]	train-rmse:90115.9	test-rmse:90554
# [36]	train-rmse:90083.4	test-rmse:90527.4
# [37]	train-rmse:90056	test-rmse:90504.7
# [38]	train-rmse:90027.7	test-rmse:90481.7
# [39]	train-rmse:90003.9	test-rmse:90463
# [40]	train-rmse:89978.5	test-rmse:90441.6
# [41]	train-rmse:89961.8	test-rmse:90429.4
# [42]	train-rmse:89941.6	test-rmse:90413.4
# [43]	train-rmse:89921.7	test-rmse:90397.9
# [44]	train-rmse:89901.7	test-rmse:90385.4
# [45]	train-rmse:89886	test-rmse:90374.8
# [46]	train-rmse:89871.5	test-rmse:90364.4
# [47]	train-rmse:89859.3	test-rmse:90357.3
# [48]	train-rmse:89845.1	test-rmse:90348.4
# [49]	train-rmse:89827.9	test-rmse:90335.8
# [50]	train-rmse:89813.8	test-rmse:90327.5
# [51]	train-rmse:89796.6	test-rmse:90315.4
# [52]	train-rmse:89780.1	test-rmse:90303.9
# [53]	train-rmse:89767.4	test-rmse:90295.7
# [54]	train-rmse:89756.5	test-rmse:90288.4
# [55]	train-rmse:89746	test-rmse:90282.4
# [56]	train-rmse:89733.7	test-rmse:90275
# [57]	train-rmse:89719.3	test-rmse:90265.3
# [58]	train-rmse:89707.1	test-rmse:90258.3
# [59]	train-rmse:89695.6	test-rmse:90250.7
# [60]	train-rmse:89685.3	test-rmse:90245.7
# [61]	train-rmse:89671.9	test-rmse:90237
# [62]	train-rmse:89659.8	test-rmse:90229.6
# [63]	train-rmse:89648.6	test-rmse:90224.1
# [64]	train-rmse:89634.5	test-rmse:90214.9
# [65]	train-rmse:89626	test-rmse:90211.9
# [66]	train-rmse:89618.1	test-rmse:90207.8
# [67]	train-rmse:89608.5	test-rmse:90202
# [68]	train-rmse:89595.4	test-rmse:90193.2
# [69]	train-rmse:89585	test-rmse:90188.1
# [70]	train-rmse:89572.6	test-rmse:90181
# [71]	train-rmse:89566	test-rmse:90177.4
# [72]	train-rmse:89556.2	test-rmse:90171.2
# [73]	train-rmse:89547.5	test-rmse:90166.3
# [74]	train-rmse:89537.5	test-rmse:90161.8
# [75]	train-rmse:89524.5	test-rmse:90154.5
# [76]	train-rmse:89517.2	test-rmse:90151.3
# [77]	train-rmse:89504.7	test-rmse:90143.9
# [78]	train-rmse:89493.1	test-rmse:90135.9
# [79]	train-rmse:89482.1	test-rmse:90130
# [80]	train-rmse:89472.2	test-rmse:90124.4
# [81]	train-rmse:89460.9	test-rmse:90118.7
# [82]	train-rmse:89452.6	test-rmse:90114.7
# [83]	train-rmse:89442.8	test-rmse:90109.3
# [84]	train-rmse:89437.5	test-rmse:90106.5
# [85]	train-rmse:89433.4	test-rmse:90105.3
# [86]	train-rmse:89424.3	test-rmse:90100.9
# [87]	train-rmse:89415.5	test-rmse:90097.7
# [88]	train-rmse:89406.7	test-rmse:90094.4
# [89]	train-rmse:89400.7	test-rmse:90091.8
# [90]	train-rmse:89392	test-rmse:90087.6
# [91]	train-rmse:89386.5	test-rmse:90086.1
# [92]	train-rmse:89374.6	test-rmse:90080.4
# [93]	train-rmse:89367.8	test-rmse:90077.1
# [94]	train-rmse:89359.5	test-rmse:90074
# [95]	train-rmse:89349.5	test-rmse:90068.4
# [96]	train-rmse:89342.8	test-rmse:90066.2
# [97]	train-rmse:89335.7	test-rmse:90062.4
# [98]	train-rmse:89329.1	test-rmse:90058.9
# [99]	train-rmse:89324.6	test-rmse:90056.5
# [100]	train-rmse:89318.5	test-rmse:90054.8
# [101]	train-rmse:89312.8	test-rmse:90052.2
# [102]	train-rmse:89306.1	test-rmse:90050.9
# [103]	train-rmse:89299.2	test-rmse:90047.6
# [104]	train-rmse:89293.8	test-rmse:90045.7
# [105]	train-rmse:89289.6	test-rmse:90043.7
# [106]	train-rmse:89280.8	test-rmse:90039.8
# [107]	train-rmse:89273	test-rmse:90037.3
# [108]	train-rmse:89267.3	test-rmse:90035
# [109]	train-rmse:89257.6	test-rmse:90029.8
# [110]	train-rmse:89251.5	test-rmse:90026.9
# [111]	train-rmse:89242.1	test-rmse:90022.8
# [112]	train-rmse:89234.4	test-rmse:90018.6
# [113]	train-rmse:89227	test-rmse:90015.4
# [114]	train-rmse:89218.9	test-rmse:90012
# [115]	train-rmse:89213.8	test-rmse:90011.1
# [116]	train-rmse:89210.8	test-rmse:90009.4
# [117]	train-rmse:89202.7	test-rmse:90005.6
# [118]	train-rmse:89194.8	test-rmse:90001.3
# [119]	train-rmse:89187.3	test-rmse:89998.8
# [120]	train-rmse:89179.7	test-rmse:89995.3
# [121]	train-rmse:89170.9	test-rmse:89991.4
# [122]	train-rmse:89166	test-rmse:89990.2
# [123]	train-rmse:89162.1	test-rmse:89988.6
# [124]	train-rmse:89155.8	test-rmse:89986.5
# [125]	train-rmse:89151.8	test-rmse:89984.9
# [126]	train-rmse:89147	test-rmse:89983.2
# [127]	train-rmse:89141.2	test-rmse:89981.5
# [128]	train-rmse:89135.7	test-rmse:89980.1
# [129]	train-rmse:89132.2	test-rmse:89979.2
# [130]	train-rmse:89125.8	test-rmse:89977.5
# [131]	train-rmse:89120.8	test-rmse:89975
# [132]	train-rmse:89112.3	test-rmse:89971.4
# [133]	train-rmse:89106.5	test-rmse:89968.7
# [134]	train-rmse:89103.2	test-rmse:89967.9
# [135]	train-rmse:89093.2	test-rmse:89962.2
# [136]	train-rmse:89085.4	test-rmse:89959.3
# [137]	train-rmse:89078.6	test-rmse:89958.2
# [138]	train-rmse:89074.3	test-rmse:89956.7
# [139]	train-rmse:89065.2	test-rmse:89952.8
# [140]	train-rmse:89059	test-rmse:89950.8
# [141]	train-rmse:89054.3	test-rmse:89949.5
# [142]	train-rmse:89049.9	test-rmse:89946.7
# [143]	train-rmse:89045.1	test-rmse:89945.3
# [144]	train-rmse:89038.8	test-rmse:89942.7
# [145]	train-rmse:89033.4	test-rmse:89941.3
# [146]	train-rmse:89029.8	test-rmse:89940.2
# [147]	train-rmse:89025.5	test-rmse:89939.3
# [148]	train-rmse:89019.1	test-rmse:89936.4
# [149]	train-rmse:89015.2	test-rmse:89935.3
# [150]	train-rmse:89008.3	test-rmse:89933.4
# [151]	train-rmse:89001	test-rmse:89930.4
# [152]	train-rmse:88995.2	test-rmse:89927.8
# [153]	train-rmse:88992.1	test-rmse:89926.8
# [154]	train-rmse:88986.1	test-rmse:89925.2
# [155]	train-rmse:88981.2	test-rmse:89923.7
# [156]	train-rmse:88977.6	test-rmse:89922.8
# [157]	train-rmse:88969.7	test-rmse:89920.4
# [158]	train-rmse:88965	test-rmse:89918.1
# [159]	train-rmse:88961.8	test-rmse:89917.5
# [160]	train-rmse:88955.8	test-rmse:89915.8
# [161]	train-rmse:88952.5	test-rmse:89914.7
# [162]	train-rmse:88948.4	test-rmse:89914.3
# [163]	train-rmse:88942.1	test-rmse:89913.4
# [164]	train-rmse:88937.9	test-rmse:89911.8
# [165]	train-rmse:88932.1	test-rmse:89910.4
# [166]	train-rmse:88924.9	test-rmse:89907.9
# [167]	train-rmse:88922.6	test-rmse:89907.2
# [168]	train-rmse:88919.4	test-rmse:89907.2
# [169]	train-rmse:88915.4	test-rmse:89906.1
# [170]	train-rmse:88910.1	test-rmse:89905.2
# [171]	train-rmse:88905.5	test-rmse:89905.5
# [172]	train-rmse:88901.6	test-rmse:89904.9
# [173]	train-rmse:88894.7	test-rmse:89902.2
# [174]	train-rmse:88890.3	test-rmse:89900.8
# [175]	train-rmse:88886.3	test-rmse:89900.4
# [176]	train-rmse:88879.7	test-rmse:89898.6
# [177]	train-rmse:88877.8	test-rmse:89898
# [178]	train-rmse:88873.6	test-rmse:89896.4
# [179]	train-rmse:88869.8	test-rmse:89896.3
# [180]	train-rmse:88865.7	test-rmse:89895.7
# [181]	train-rmse:88862.3	test-rmse:89895.5
# [182]	train-rmse:88856.5	test-rmse:89894.2
# [183]	train-rmse:88851.7	test-rmse:89894
# [184]	train-rmse:88849.5	test-rmse:89893.8
# [185]	train-rmse:88845.8	test-rmse:89892.8
# [186]	train-rmse:88838.1	test-rmse:89890
# [187]	train-rmse:88832.7	test-rmse:89889.1
# [188]	train-rmse:88828.8	test-rmse:89889.1
# [189]	train-rmse:88824.9	test-rmse:89889.1
# [190]	train-rmse:88821.9	test-rmse:89888.3
# [191]	train-rmse:88818.2	test-rmse:89887
# [192]	train-rmse:88815	test-rmse:89886.3
# [193]	train-rmse:88811.3	test-rmse:89885.8
# [194]	train-rmse:88808.6	test-rmse:89885.4
# [195]	train-rmse:88803.1	test-rmse:89884.3
# [196]	train-rmse:88798.8	test-rmse:89883.3
# [197]	train-rmse:88792.4	test-rmse:89882.3
# [198]	train-rmse:88789.8	test-rmse:89881.6
# [199]	train-rmse:88783.4	test-rmse:89880.3
# [200]	train-rmse:88779	test-rmse:89877.4
# [201]	train-rmse:88775.1	test-rmse:89876.6
# [202]	train-rmse:88772.3	test-rmse:89876.5
# [203]	train-rmse:88769.5	test-rmse:89876.3
# [204]	train-rmse:88764.4	test-rmse:89875.1
# [205]	train-rmse:88759.3	test-rmse:89874.5
# [206]	train-rmse:88752.5	test-rmse:89871.7
# [207]	train-rmse:88746.7	test-rmse:89871.1
# [208]	train-rmse:88744.2	test-rmse:89870.6
# [209]	train-rmse:88742	test-rmse:89870.3
# [210]	train-rmse:88736.6	test-rmse:89869
# [211]	train-rmse:88733.6	test-rmse:89868.2
# [212]	train-rmse:88729.6	test-rmse:89867.8
# [213]	train-rmse:88725.6	test-rmse:89867.5
# [214]	train-rmse:88720.3	test-rmse:89865
# [215]	train-rmse:88717.6	test-rmse:89864.3
# [216]	train-rmse:88714.8	test-rmse:89864.4
# [217]	train-rmse:88710.5	test-rmse:89864.1
# [218]	train-rmse:88708.3	test-rmse:89864.3
# [219]	train-rmse:88702.6	test-rmse:89862.4
# [220]	train-rmse:88698.5	test-rmse:89861.4
# [221]	train-rmse:88693.9	test-rmse:89860.7
# [222]	train-rmse:88688.4	test-rmse:89858.7
# [223]	train-rmse:88685.6	test-rmse:89857.8
# [224]	train-rmse:88681.9	test-rmse:89857.1
# [225]	train-rmse:88679.9	test-rmse:89856.6
# [226]	train-rmse:88674	test-rmse:89855.4
# [227]	train-rmse:88669.8	test-rmse:89855.1
# [228]	train-rmse:88665	test-rmse:89854.6
# [229]	train-rmse:88662.7	test-rmse:89854.2
# [230]	train-rmse:88657.7	test-rmse:89852.3
# [231]	train-rmse:88655.2	test-rmse:89852
# [232]	train-rmse:88652.6	test-rmse:89851.8
# [233]	train-rmse:88648.4	test-rmse:89851.2
# [234]	train-rmse:88643.6	test-rmse:89850.3
# [235]	train-rmse:88640	test-rmse:89849.1
# [236]	train-rmse:88637.4	test-rmse:89848.3
# [237]	train-rmse:88631.5	test-rmse:89847.3
# [238]	train-rmse:88628	test-rmse:89846.7
# [239]	train-rmse:88623.9	test-rmse:89846.1
# [240]	train-rmse:88617.8	test-rmse:89844.1
# [241]	train-rmse:88615.1	test-rmse:89844.2
# [242]	train-rmse:88612.6	test-rmse:89843.5
# [243]	train-rmse:88607.5	test-rmse:89842.2
# [244]	train-rmse:88602.8	test-rmse:89840.8
# [245]	train-rmse:88598.7	test-rmse:89840.3
# [246]	train-rmse:88593.8	test-rmse:89839.9
# [247]	train-rmse:88590.7	test-rmse:89840
# [248]	train-rmse:88587.9	test-rmse:89840.2
# [249]	train-rmse:88585.6	test-rmse:89840.1
# [250]	train-rmse:88580.5	test-rmse:89839.9
# [251]	train-rmse:88577.3	test-rmse:89839.2
# [252]	train-rmse:88571.8	test-rmse:89837.4
# [253]	train-rmse:88566.5	test-rmse:89837
# [254]	train-rmse:88561.4	test-rmse:89835
# [255]	train-rmse:88555.5	test-rmse:89834.3
# [256]	train-rmse:88552.6	test-rmse:89833.6
# [257]	train-rmse:88550.9	test-rmse:89833.3
# [258]	train-rmse:88548.9	test-rmse:89832.8
# [259]	train-rmse:88545.4	test-rmse:89833
# [260]	train-rmse:88543	test-rmse:89832.2
# [261]	train-rmse:88538.3	test-rmse:89832.1
# [262]	train-rmse:88534.6	test-rmse:89831.3
# [263]	train-rmse:88530.6	test-rmse:89830.9
# [264]	train-rmse:88527.1	test-rmse:89830.4
# [265]	train-rmse:88524.6	test-rmse:89830
# [266]	train-rmse:88519.5	test-rmse:89828.2
# [267]	train-rmse:88514.1	test-rmse:89827.5
# [268]	train-rmse:88512.6	test-rmse:89827.2
# [269]	train-rmse:88507.8	test-rmse:89826.4
# [270]	train-rmse:88502.7	test-rmse:89826.2
# [271]	train-rmse:88498.6	test-rmse:89825.3
# [272]	train-rmse:88492.4	test-rmse:89823.6
# [273]	train-rmse:88489.6	test-rmse:89823.4
# [274]	train-rmse:88487.1	test-rmse:89823.4
# [275]	train-rmse:88484.7	test-rmse:89822.8
# [276]	train-rmse:88480.5	test-rmse:89821.8
# [277]	train-rmse:88479.5	test-rmse:89821.6
# [278]	train-rmse:88476.8	test-rmse:89821.5
# [279]	train-rmse:88472.6	test-rmse:89821.1
# [280]	train-rmse:88467.5	test-rmse:89820.2
# [281]	train-rmse:88463.4	test-rmse:89819.7
# [282]	train-rmse:88459.5	test-rmse:89819.5
# [283]	train-rmse:88453.4	test-rmse:89817.1
# [284]	train-rmse:88449.2	test-rmse:89816.8
# [285]	train-rmse:88446	test-rmse:89816.5
# [286]	train-rmse:88442.9	test-rmse:89816.4
# [287]	train-rmse:88439.1	test-rmse:89816.1
# [288]	train-rmse:88436.1	test-rmse:89816.8
# [289]	train-rmse:88431.8	test-rmse:89817.1
# [290]	train-rmse:88430	test-rmse:89816.8
# [291]	train-rmse:88425	test-rmse:89815.9
# [292]	train-rmse:88421.2	test-rmse:89815.8
# [293]	train-rmse:88414.4	test-rmse:89813.1
# [294]	train-rmse:88408.6	test-rmse:89810.9
# [295]	train-rmse:88404.1	test-rmse:89810.3
# [296]	train-rmse:88401.2	test-rmse:89810.4
# [297]	train-rmse:88399.3	test-rmse:89810.5
# [298]	train-rmse:88396.5	test-rmse:89810.1
# [299]	train-rmse:88393.4	test-rmse:89809.8
# [300]	train-rmse:88390.6	test-rmse:89809.4
# [301]	train-rmse:88389.7	test-rmse:89809.4
# [302]	train-rmse:88385.5	test-rmse:89807.5
# [303]	train-rmse:88381.2	test-rmse:89806.7
# [304]	train-rmse:88377	test-rmse:89806.3
# [305]	train-rmse:88373.3	test-rmse:89805.7
# [306]	train-rmse:88370.2	test-rmse:89805.6
# [307]	train-rmse:88366.8	test-rmse:89805.3
# [308]	train-rmse:88362	test-rmse:89804.4
# [309]	train-rmse:88357.8	test-rmse:89803.7
# [310]	train-rmse:88355.3	test-rmse:89803.3
# [311]	train-rmse:88351.5	test-rmse:89802.8
# [312]	train-rmse:88348.6	test-rmse:89802.1
# [313]	train-rmse:88345.2	test-rmse:89801.5
# [314]	train-rmse:88340.9	test-rmse:89800.7
# [315]	train-rmse:88335.9	test-rmse:89798.8
# [316]	train-rmse:88332.1	test-rmse:89798.1
# [317]	train-rmse:88326.6	test-rmse:89797.5
# [318]	train-rmse:88321.4	test-rmse:89796.9
# [319]	train-rmse:88317.7	test-rmse:89796.8
# [320]	train-rmse:88314.1	test-rmse:89797.4
# [321]	train-rmse:88310.4	test-rmse:89796.9
# [322]	train-rmse:88307.5	test-rmse:89796.5
# [323]	train-rmse:88304.2	test-rmse:89796.1
# [324]	train-rmse:88299.6	test-rmse:89795.6
# [325]	train-rmse:88297.7	test-rmse:89795
# [326]	train-rmse:88294.4	test-rmse:89794.6
# [327]	train-rmse:88292.9	test-rmse:89794.7
# [328]	train-rmse:88290.6	test-rmse:89794.9
# [329]	train-rmse:88288.5	test-rmse:89794.8
# [330]	train-rmse:88283.8	test-rmse:89794.4
# [331]	train-rmse:88279.9	test-rmse:89793.5
# [332]	train-rmse:88277.1	test-rmse:89792.6
# [333]	train-rmse:88276.2	test-rmse:89792.3
# [334]	train-rmse:88272.9	test-rmse:89792.7
# [335]	train-rmse:88271.1	test-rmse:89792.3
# [336]	train-rmse:88269	test-rmse:89791.8
# [337]	train-rmse:88264.5	test-rmse:89791.2
# [338]	train-rmse:88261.9	test-rmse:89791.1
# [339]	train-rmse:88256.8	test-rmse:89790.6
# [340]	train-rmse:88254.8	test-rmse:89790.2
# [341]	train-rmse:88254	test-rmse:89790
# [342]	train-rmse:88250.6	test-rmse:89790.6
# [343]	train-rmse:88245.6	test-rmse:89790.5
# [344]	train-rmse:88241.6	test-rmse:89790.1
# [345]	train-rmse:88237	test-rmse:89788.8
# [346]	train-rmse:88234.8	test-rmse:89788.7
# [347]	train-rmse:88230.9	test-rmse:89787.8
# [348]	train-rmse:88225.7	test-rmse:89787.6
# [349]	train-rmse:88221.7	test-rmse:89787.1
# [350]	train-rmse:88215.8	test-rmse:89785.9
# [351]	train-rmse:88211.8	test-rmse:89784.6
# [352]	train-rmse:88209.6	test-rmse:89784.6
# [353]	train-rmse:88205.9	test-rmse:89784.5
# [354]	train-rmse:88202.8	test-rmse:89784.5
# [355]	train-rmse:88199.2	test-rmse:89783.9
# [356]	train-rmse:88194.3	test-rmse:89782.8
# [357]	train-rmse:88192.2	test-rmse:89782.9
# [358]	train-rmse:88187	test-rmse:89781.1
# [359]	train-rmse:88182.9	test-rmse:89780.8
# [360]	train-rmse:88180.9	test-rmse:89781.2
# [361]	train-rmse:88178.5	test-rmse:89781.3
# [362]	train-rmse:88176.7	test-rmse:89782
# [363]	train-rmse:88171.3	test-rmse:89780.5
# [364]	train-rmse:88167.4	test-rmse:89780.6
# [365]	train-rmse:88165.7	test-rmse:89780.5
# [366]	train-rmse:88163.5	test-rmse:89780.2
# [367]	train-rmse:88162.8	test-rmse:89780.3
# [368]	train-rmse:88160.5	test-rmse:89780.5
# [369]	train-rmse:88157.5	test-rmse:89780.3
# [370]	train-rmse:88152.2	test-rmse:89780.3
# [371]	train-rmse:88150	test-rmse:89780.6
# [372]	train-rmse:88148.3	test-rmse:89780.3
# [373]	train-rmse:88146.1	test-rmse:89780.2
# [374]	train-rmse:88144.3	test-rmse:89780.1
# [375]	train-rmse:88142.1	test-rmse:89779.6
# [376]	train-rmse:88140.1	test-rmse:89779.6
# [377]	train-rmse:88136.3	test-rmse:89779.3
# [378]	train-rmse:88132.8	test-rmse:89779.7
# [379]	train-rmse:88130	test-rmse:89779.9
# [380]	train-rmse:88126.1	test-rmse:89779.8
# [381]	train-rmse:88121.4	test-rmse:89779.6
# [382]	train-rmse:88116.9	test-rmse:89779.1
# [383]	train-rmse:88111.8	test-rmse:89778.5
# [384]	train-rmse:88107.1	test-rmse:89778.6
# [385]	train-rmse:88103.9	test-rmse:89778.2
# [386]	train-rmse:88099.7	test-rmse:89778.6
# [387]	train-rmse:88097.2	test-rmse:89778.5
# [388]	train-rmse:88092.8	test-rmse:89779.1
# [389]	train-rmse:88091.3	test-rmse:89778.9
# [390]	train-rmse:88087.9	test-rmse:89778.3
# [391]	train-rmse:88083.4	test-rmse:89776.7
# [392]	train-rmse:88081.4	test-rmse:89777.1
# [393]	train-rmse:88079.5	test-rmse:89777
# [394]	train-rmse:88075.2	test-rmse:89776.2
# [395]	train-rmse:88072.7	test-rmse:89776.1
# [396]	train-rmse:88070.6	test-rmse:89775.8
# [397]	train-rmse:88067.6	test-rmse:89775.6
# [398]	train-rmse:88064.1	test-rmse:89776.2
# [399]	train-rmse:88061.8	test-rmse:89776.1
# [400]	train-rmse:88059.4	test-rmse:89776
# [401]	train-rmse:88054.6	test-rmse:89775.6
# [402]	train-rmse:88051.6	test-rmse:89775.8
# [403]	train-rmse:88049.7	test-rmse:89775.8
# [404]	train-rmse:88045.7	test-rmse:89775.4
# [405]	train-rmse:88043.7	test-rmse:89775.5
# [406]	train-rmse:88040.4	test-rmse:89775.6
# [407]	train-rmse:88037.6	test-rmse:89775.6
# [408]	train-rmse:88033.4	test-rmse:89775.7
# [409]	train-rmse:88029.8	test-rmse:89775.2
# [410]	train-rmse:88026.6	test-rmse:89775.5
# [411]	train-rmse:88022.2	test-rmse:89775.1
# [412]	train-rmse:88019.7	test-rmse:89774.9
# [413]	train-rmse:88018.4	test-rmse:89774.6
# [414]	train-rmse:88016	test-rmse:89774.9
# [415]	train-rmse:88011.2	test-rmse:89774.1
# [416]	train-rmse:88007.5	test-rmse:89773.3
# [417]	train-rmse:88005.3	test-rmse:89773.6
# [418]	train-rmse:88003.2	test-rmse:89773.5
# [419]	train-rmse:87998.5	test-rmse:89773.3
# [420]	train-rmse:87993.7	test-rmse:89773.3
# [421]	train-rmse:87991.1	test-rmse:89773.3
# [422]	train-rmse:87987	test-rmse:89773.5
# [423]	train-rmse:87983.9	test-rmse:89773.2
# [424]	train-rmse:87981.2	test-rmse:89773.1
# [425]	train-rmse:87978	test-rmse:89773
# [426]	train-rmse:87976.8	test-rmse:89772.8
# [427]	train-rmse:87972.7	test-rmse:89772
# [428]	train-rmse:87968.6	test-rmse:89771.6
# [429]	train-rmse:87967.7	test-rmse:89771.7
# [430]	train-rmse:87965.8	test-rmse:89771.4
# [431]	train-rmse:87963.2	test-rmse:89771.7
# [432]	train-rmse:87962.7	test-rmse:89771.8
# [433]	train-rmse:87959.6	test-rmse:89771.8
# [434]	train-rmse:87955.6	test-rmse:89771.4
# [435]	train-rmse:87953.8	test-rmse:89771.1
# [436]	train-rmse:87949.6	test-rmse:89771.2
# [437]	train-rmse:87945.5	test-rmse:89771.3
# [438]	train-rmse:87942.4	test-rmse:89770.5
# [439]	train-rmse:87938.8	test-rmse:89770.5
# [440]	train-rmse:87935.9	test-rmse:89770.5
# [441]	train-rmse:87931	test-rmse:89770.8
# [442]	train-rmse:87926	test-rmse:89771
# [443]	train-rmse:87922.6	test-rmse:89770.7
# [444]	train-rmse:87919.6	test-rmse:89770.9
# [445]	train-rmse:87916.2	test-rmse:89770.8
# [446]	train-rmse:87912.9	test-rmse:89770.8
# [447]	train-rmse:87908.9	test-rmse:89770.2
# [448]	train-rmse:87905.4	test-rmse:89770
# [449]	train-rmse:87902.8	test-rmse:89770
# [450]	train-rmse:87899.1	test-rmse:89769.9
# [451]	train-rmse:87896.6	test-rmse:89770.1
# [452]	train-rmse:87894.3	test-rmse:89769.5
# [453]	train-rmse:87892	test-rmse:89769.6
# [454]	train-rmse:87890.2	test-rmse:89769.3
# [455]	train-rmse:87887.8	test-rmse:89769.4
# [456]	train-rmse:87885.7	test-rmse:89769.4
# [457]	train-rmse:87883.3	test-rmse:89769.6
# [458]	train-rmse:87880.1	test-rmse:89770
# [459]	train-rmse:87877.8	test-rmse:89769.7
# [460]	train-rmse:87874.2	test-rmse:89769.5
# [461]	train-rmse:87870.3	test-rmse:89769.2
# [462]	train-rmse:87867.8	test-rmse:89768.7
# [463]	train-rmse:87865.8	test-rmse:89768.5
# [464]	train-rmse:87863.3	test-rmse:89768.7
# [465]	train-rmse:87859.7	test-rmse:89768
# [466]	train-rmse:87856.2	test-rmse:89767.9
# [467]	train-rmse:87853.3	test-rmse:89767.9
# [468]	train-rmse:87850.5	test-rmse:89767.8
# [469]	train-rmse:87849.2	test-rmse:89767.5
# [470]	train-rmse:87847.4	test-rmse:89767.3
# [471]	train-rmse:87844.9	test-rmse:89767.2
# [472]	train-rmse:87841.8	test-rmse:89767.2
# [473]	train-rmse:87839.9	test-rmse:89767.1
# [474]	train-rmse:87836.4	test-rmse:89767.3
# [475]	train-rmse:87833.2	test-rmse:89767.2
# [476]	train-rmse:87830.3	test-rmse:89767.2
# [477]	train-rmse:87826.7	test-rmse:89766
# [478]	train-rmse:87826.2	test-rmse:89765.7
# [479]	train-rmse:87822.7	test-rmse:89765.6
# [480]	train-rmse:87819.6	test-rmse:89765.3
# [481]	train-rmse:87816.2	test-rmse:89765.1
# [482]	train-rmse:87812.8	test-rmse:89764.9
# [483]	train-rmse:87809.4	test-rmse:89764.4
# [484]	train-rmse:87806.9	test-rmse:89764.3
# [485]	train-rmse:87803.5	test-rmse:89764
# [486]	train-rmse:87800.4	test-rmse:89763.5
# [487]	train-rmse:87797.9	test-rmse:89763.5
# [488]	train-rmse:87795.2	test-rmse:89763
# [489]	train-rmse:87792.4	test-rmse:89762.9
# [490]	train-rmse:87789.6	test-rmse:89763.3
# [491]	train-rmse:87788	test-rmse:89763
# [492]	train-rmse:87787.3	test-rmse:89762.8
# [493]	train-rmse:87785.5	test-rmse:89763.1
# [494]	train-rmse:87784.2	test-rmse:89763.1
# [495]	train-rmse:87780.2	test-rmse:89762.9
# [496]	train-rmse:87776.8	test-rmse:89762.8
# [497]	train-rmse:87774.7	test-rmse:89762.7
# [498]	train-rmse:87770.5	test-rmse:89762.3
# [499]	train-rmse:87767.6	test-rmse:89762.9
# [500]	train-rmse:87764.7	test-rmse:89762.5
# [501]	train-rmse:87763.3	test-rmse:89762.3
# [502]	train-rmse:87760.9	test-rmse:89762.5
# [503]	train-rmse:87757.4	test-rmse:89761.9
# [504]	train-rmse:87754.8	test-rmse:89761.7
# [505]	train-rmse:87751.3	test-rmse:89761.4
# [506]	train-rmse:87748.6	test-rmse:89761.4
# [507]	train-rmse:87745.4	test-rmse:89761.6
# [508]	train-rmse:87743	test-rmse:89761.4
# [509]	train-rmse:87739.8	test-rmse:89761.5
# [510]	train-rmse:87735.9	test-rmse:89761.7
# [511]	train-rmse:87734.5	test-rmse:89761.7
# [512]	train-rmse:87732.1	test-rmse:89761.6
# [513]	train-rmse:87731.2	test-rmse:89761.5
# [514]	train-rmse:87729.1	test-rmse:89761.5
# [515]	train-rmse:87727.2	test-rmse:89761.4
# [516]	train-rmse:87725.7	test-rmse:89761.7
# [517]	train-rmse:87722.9	test-rmse:89761.7
# [518]	train-rmse:87720.2	test-rmse:89761.9
# [519]	train-rmse:87717.4	test-rmse:89762
# [520]	train-rmse:87715	test-rmse:89761.6
# [521]	train-rmse:87712.2	test-rmse:89761.5
# [522]	train-rmse:87708.5	test-rmse:89761.6
# [523]	train-rmse:87705.5	test-rmse:89761.7
# [524]	train-rmse:87703.6	test-rmse:89762.2
# [525]	train-rmse:87701.3	test-rmse:89762.5
# [526]	train-rmse:87699.2	test-rmse:89762.3
# [527]	train-rmse:87696.4	test-rmse:89762.2
# [528]	train-rmse:87693.3	test-rmse:89763.2
# [529]	train-rmse:87690	test-rmse:89763.4
# [530]	train-rmse:87688.1	test-rmse:89763.4
# [531]	train-rmse:87686.8	test-rmse:89763.3
# [532]	train-rmse:87685.1	test-rmse:89763.5
# [533]	train-rmse:87681	test-rmse:89762.7
# [534]	train-rmse:87678	test-rmse:89763.2
# [535]	train-rmse:87675.3	test-rmse:89762.8
# Stopping. Best iteration:
# [515]	train-rmse:87727.2	test-rmse:89761.4

# %% [markdown]
# ### No mejora

# %% [markdown]
# ---

# %% [markdown]
# ## Comparacion entre valores reales y las predicciones

# %%
predicciones = pd.DataFrame(y_pred)

# %%
predicciones.rename(columns = {0:"predicciones"},inplace = True)

# %%
predicciones.min()
# Out:
# predicciones   -14869.337891
# dtype: float32

# %% [markdown]
# #### Predice valores negativos

# %%
reales = pd.DataFrame(y_test)

# %%
reales.reset_index(inplace = True)

# %% [markdown]
# ---

# %% [markdown]
# ### Dataframe para analizar las predicciones

# %%
comparacion = pd.concat([reales,predicciones],axis =1)

# %%
comparacion["diferencia"] = abs(comparacion["target"] - comparacion["predicciones"])

# %%
comparacion.head()
# Out:
#                  index         target   predicciones    diferencia
# 0  7070259910184666175   94428.065217  160653.562500  66225.497283
# 1  7880352965021259662  259200.000000  168100.890625  91099.109375
# 2  9084979779488171907   48199.287436   48873.023438    673.736002
# 3  6857664753040153514   25019.739424    1867.900024  23151.839400
# 4  2989480118998387606  227415.276563  169257.000000  58158.276563

# %%
mas_errados = comparacion.sort_values(by = "diferencia",ascending = False)

# %%
mas_errados.reset_index(inplace = True)

# %%
cien_mas_errados = mas_errados.iloc[:100,:]

# %%
cien_mas_errados.drop(columns = "level_0",inplace = True)
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ### Busco alguna similaridad entre los features de los mas errados

# %%
cien_mas_errados.set_index("index",inplace = True)

# %%
features_test = pd.DataFrame(X_test)

# %%
cien_mas_errados_features = features_test[(features_test.index).isin(cien_mas_errados.index)]

# %% [markdown]
# ---

# %% [markdown]
# #### Calculo el coseno

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
matriz_similaridad = pd.DataFrame(cosine_similarity(cien_mas_errados_features))

# %%
matriz_similaridad.describe().loc["mean"].max()
# Out:
# 0.8026917587220301

# %%
matriz_similaridad[matriz_similaridad.describe().loc["mean"] == 0.8026917587220301]
# Out:
#          0         1         2         3         4         5         6    \
# 56  0.904392  0.890587  0.965803  0.503611  0.901825  0.805212  0.608572
#
#          7        8         9    ...       162       163       164       165  \
# 56  0.962171  0.83049  0.632456  ...  0.716329  0.906465  0.813679  0.647316
#
#          166       167       168       169       170       171
# 56  0.965281  0.971265  0.739158  0.797433  0.878662  0.585701
#
# [1 rows x 172 columns]

# %% [markdown]
# ##### ¿La fila 56 es la más similar a todas ?

# %%
cien_mas_errados_features.iloc[56]
# Out:
# cant_eventos_2                                   0.000000
# cantidad_apariciones                           514.000000
# apariciones_en_hora_0                           61.000000
# apariciones_en_hora_1                            8.000000
# apariciones_en_hora_2                            1.000000
# apariciones_en_hora_3                           65.000000
# apariciones_en_hora_4                           39.000000
# apariciones_en_hora_5                           18.000000
# apariciones_en_hora_6                           13.000000
# apariciones_en_hora_7                           57.000000
# apariciones_en_hora_8                            0.000000
# apariciones_en_hora_9                           47.000000
# apariciones_en_hora_10                          16.000000
# apariciones_en_hora_11                          83.000000
# apariciones_en_hora_12                           0.000000
# apariciones_en_hora_13                           0.000000
# apariciones_en_hora_14                           0.000000
# apariciones_en_hora_15                          11.000000
# apariciones_en_hora_16                          33.000000
# apariciones_en_hora_17                          13.000000
# apariciones_en_hora_18                           0.000000
# apariciones_en_hora_19                           8.000000
# apariciones_en_hora_20                           1.000000
# apariciones_en_hora_21                           0.000000
# apariciones_en_hora_22                           2.000000
# apariciones_en_hora_23                          38.000000
# apariciones_en_dia_1                           254.000000
# apariciones_en_dia_2                           152.000000
# apariciones_en_dia_3                           108.000000
# cantidad_so_registrados                          1.000000
#                                                  ...
# apariciones_en_source_3                        159.000000
# apariciones_en_source_4                          0.000000
# apariciones_en_source_5                          0.000000
# apariciones_en_source_6                          0.000000
# apariciones_en_source_7                          0.000000
# apariciones_en_source_8                          0.000000
# apariciones_en_source_9                          0.000000
# tiempo_ultima_aparicion_hasta_fin_ventana    14191.209599
# tiempo_hora_frec_aparicion_subasta           39600.000000
# tiempo_segunda_hora_frec_aparicion               0.000000
# cant_eventos                                     7.000000
# prom_eventos                                     3.000000
# eventos_dia_1                                    1.000000
# eventos_dia_2                                    6.000000
# eventos_dia_3                                    0.000000
# max_cant_eventos                                 3.000000
# cant_eventos_maximos                             1.000000
# segs_hasta_hora_freq                         46800.000000
# eventos_franja_1                                 0.000000
# eventos_franja_2                                 0.000000
# eventos_franja_3                                 1.000000
# eventos_franja_4                                 6.000000
# eventos_franja_5                                 0.000000
# eventos_franja_6                                 0.000000
# cant_eventos_wifi                                0.000000
# cant_eventos_sin_wifi                            7.000000
# cant_eventos_15                                  0.000000
# cant_eventos_23                                  0.000000
# cant_eventos_7                                   2.000000
# cant_eventos_0                                   0.000000
# Name: 8396276850211446666, Length: 67, dtype: float64

# %%
cien_mas_acertados = comparacion.sort_values(by = "diferencia").iloc[:100,:]

# %%
cien_mas_acertados.rename(columns = {"index":"device_id"},inplace = True)
cien_mas_acertados.reset_index(inplace = True, drop = True)

# %%
cien_mas_acertados_features = features_test[(features_test.index).isin(cien_mas_acertados["device_id"])]

# %% [markdown]
# ### Comparacion entre el más errado y el más acertado, son muy parecidos

# %%
pd.concat([cien_mas_acertados_features.iloc[1,20:50].to_frame(),cien_mas_errados_features.iloc[1,20:50].to_frame()],axis =1)
# Out:
#                                            3715172411420155167  \
# apariciones_en_hora_18                                7.000000
# apariciones_en_hora_19                                1.000000
# apariciones_en_hora_20                               12.000000
# apariciones_en_hora_21                                1.000000
# apariciones_en_hora_22                                0.000000
# apariciones_en_hora_23                                0.000000
# apariciones_en_dia_1                                  9.000000
# apariciones_en_dia_2                                  3.000000
# apariciones_en_dia_3                                 12.000000
# cantidad_so_registrados                               1.000000
# so_media                                              1.000000
# tiempo_medio_entre_apariciones                    10632.867755
# tiempo_maximo_entre_apariciones                   84338.716641
# desvio_entre_apariciones                          22804.559346
# apariciones_en_source_0                               5.000000
# apariciones_en_source_1                              15.000000
# apariciones_en_source_2                               0.000000
# apariciones_en_source_3                               2.000000
# apariciones_en_source_4                               0.000000
# apariciones_en_source_5                               0.000000
# apariciones_en_source_6                               0.000000
# apariciones_en_source_7                               1.000000
# apariciones_en_source_8                               1.000000
# apariciones_en_source_9                               0.000000
# tiempo_ultima_aparicion_hasta_fin_ventana         11041.068961
# tiempo_hora_frec_aparicion_subasta                72000.000000
# tiempo_segunda_hora_frec_aparicion                 3600.000000
# cant_eventos                                          4.000000
# prom_eventos                                          2.000000
# eventos_dia_1                                         2.000000
#
#                                            7915168687700461863
# apariciones_en_hora_18                                1.000000
# apariciones_en_hora_19                                4.000000
# apariciones_en_hora_20                                9.000000
# apariciones_en_hora_21                                0.000000
# apariciones_en_hora_22                               14.000000
# apariciones_en_hora_23                               16.000000
# apariciones_en_dia_1                                160.000000
# apariciones_en_dia_2                                 83.000000
# apariciones_en_dia_3                                 24.000000
# cantidad_so_registrados                               1.000000
# so_media                                              1.000000
# tiempo_medio_entre_apariciones                      941.185199
# tiempo_maximo_entre_apariciones                   64892.976836
# desvio_entre_apariciones                           4831.027970
# apariciones_en_source_0                               9.000000
# apariciones_en_source_1                             102.000000
# apariciones_en_source_2                               0.000000
# apariciones_en_source_3                             128.000000
# apariciones_en_source_4                              10.000000
# apariciones_en_source_5                              14.000000
# apariciones_en_source_6                               0.000000
# apariciones_en_source_7                               0.000000
# apariciones_en_source_8                               4.000000
# apariciones_en_source_9                               0.000000
# tiempo_ultima_aparicion_hasta_fin_ventana          6614.778227
# tiempo_hora_frec_aparicion_subasta                 3600.000000
# tiempo_segunda_hora_frec_aparicion                    0.000000
# cant_eventos                                          2.000000
# prom_eventos                                          2.000000
# eventos_dia_1                                         0.000000

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Prueba combinando modelo de clasificacion y regresion

# %%
X = pd.read_pickle("train_modelo_regresion")

# %%
y = pd.read_pickle("target_modelo_regresion")

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
xg_reg = xgb.XGBRegressor(max_depth = 6,
          eta =0.3,
         silent =1,
         objective = 'reg:linear',
         eval_metric = 'rmse',
          obj = 'reg:squarederror',
         colsample_bytree = 0.7,
         min_child_weight = 0.5,
         random_state = 0,
         reg_alpha = 0,
         reg_lambda = 1,
         scale_pos_weight = 1,
         learning_rate = 0.1)

# %%
xg_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.7, eta=0.3,
#        eval_metric='rmse', gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=6,
#        min_child_weight=0.5, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, obj='reg:squarederror', objective='reg:linear',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=1, subsample=1, verbosity=1)

# %%
preds = xg_reg.predict(X_test)
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 89361.352902

# %% [markdown]
# ### Cargo el modelo de clasificacion

# %%
model_clasif = xgb.Booster({'nthread':4}) #init model
model_clasif.load_model("0003.modelo_clasificacion") # load data

# %%
pred_aparicion = model_clasif.predict(xgb.DMatrix(X_test))

# %%
pred_aparicion
# Out:
# array([0.6336276 , 0.44795492, 0.8522622 , ..., 0.6916334 , 0.6740201 ,
#        0.92810464], dtype=float32)

# %%
len(pred_aparicion)
# Out:
# 161136

# %%
len(preds)
# Out:
# 161136

# %%
e = pd.concat([pd.DataFrame(preds),pd.DataFrame(y_test).reset_index()],axis = 1)

# %%
e["diferencia"] = abs(e["target"] - e[0])

# %%
e = pd.concat([e,pd.DataFrame(pred_aparicion).rename(columns = {0:"prob"})],axis = 1 )

# %%
e.head()
# Out:
#                0            device_id         target     diferencia      prob
# 0  155536.859375  8814805873927254593  259200.000000  103663.140625  0.633628
# 1  185469.453125  6666495031837421647  259200.000000   73730.546875  0.447955
# 2   72821.164062   761561416255966252   12761.007729   60060.156333  0.852262
# 3  135351.203125  2861876111560982366    4377.167662  130974.035463  0.696632
# 4  135260.968750  6145495717011428577  104222.758637   31038.210113  0.703068

# %%
e.rename(columns = {0:"tiempo_pred"},inplace = True)

# %%
e.sort_values(by = "prob",ascending = True).head()
# Out:
#           tiempo_pred            device_id         target     diferencia  \
# 147666  223972.468750  5908406985339601428  139923.348813   84049.119937
# 125465  206833.765625   355217875130678441    9653.535413  197180.230212
# 52158   206833.765625    75402801756975899  259200.000000   52366.234375
# 31533   209439.468750  6728300126665500981  259200.000000   49760.531250
# 15804   208993.062500  7038687927116636220  259200.000000   50206.937500
#
#             prob
# 147666  0.334594
# 125465  0.338058
# 52158   0.338058
# 31533   0.340475
# 15804   0.340482

# %%
maximo_valor = 259200.000000

# %%
e.head()
# Out:
#      tiempo_pred            device_id         target     diferencia      prob
# 0  155536.859375  8814805873927254593  259200.000000  103663.140625  0.633628
# 1  185469.453125  6666495031837421647  259200.000000   73730.546875  0.447955
# 2   72821.164062   761561416255966252   12761.007729   60060.156333  0.852262
# 3  135351.203125  2861876111560982366    4377.167662  130974.035463  0.696632
# 4  135260.968750  6145495717011428577  104222.758637   31038.210113  0.703068

# %%
 e["ajuste_1"] =  e.apply(lambda e : e["tiempo_pred"] if ( e["prob"] > 0.35) else maximo_valor , axis = 1)

# %%
e.head()
# Out:
#      tiempo_pred            device_id         target     diferencia      prob  \
# 0  155536.859375  8814805873927254593  259200.000000  103663.140625  0.633628
# 1  185469.453125  6666495031837421647  259200.000000   73730.546875  0.447955
# 2   72821.164062   761561416255966252   12761.007729   60060.156333  0.852262
# 3  135351.203125  2861876111560982366    4377.167662  130974.035463  0.696632
# 4  135260.968750  6145495717011428577  104222.758637   31038.210113  0.703068
#
#         ajuste_1
# 0  155536.859375
# 1  185469.453125
# 2   72821.164062
# 3  135351.203125
# 4  135260.968750

# %%
rmse = np.sqrt(mean_squared_error(y_test, e["ajuste_1"]))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 89364.820285

# %% [markdown]
# ##### Empeora con respecto a RMSE: 89361.352902

# %% [markdown]
# ---

# %%
train = pd.read_pickle("../../armado_datos/train_auctions_doble_ventana")

# %%
len(train)
# Out:
# 643094

# %%
X, y = train.drop(columns = "target"), train["target"]
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, random_state=0)

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test, label=y_test)

param = {'max_depth':6,
         'eta':0.3,
         'silent':1,
         'objective':'reg:linear',
         'eval_metric' : 'rmse',
         'obj' : 'reg:squarederror',
         'colsample_bytree' : 0.7,
         'min_child_weight' : 0.5,
         'random_state' : 0,
         'reg_alpha' : 0,
         'reg_lambda' : 1,
         'scale_pos_weight' : 1,
         'learning_rate' : 0.1}


num_round = 5000
stopping = 40
bst = xgb.train(param, dtrain, num_round, evals=[(dtrain, "train"), (dtest, "test")], early_stopping_rounds=stopping)
#Stopping. Best iteration:
# Out:
# /home/pelozo/anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	train-rmse:148032	test-rmse:148372
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 40 rounds.
# [1]	train-rmse:138846	test-rmse:139201
# [2]	train-rmse:130960	test-rmse:131323
# [3]	train-rmse:124138	test-rmse:124508
# [4]	train-rmse:118318	test-rmse:118703
# [5]	train-rmse:113373	test-rmse:113769
# [6]	train-rmse:109188	test-rmse:109585
# [7]	train-rmse:105669	test-rmse:106073
# [8]	train-rmse:102715	test-rmse:103123
# [9]	train-rmse:100241	test-rmse:100655
# [10]	train-rmse:98207.5	test-rmse:98624.1
# [11]	train-rmse:96505.7	test-rmse:96930
# [12]	train-rmse:95105.5	test-rmse:95530.9
# [13]	train-rmse:93965.3	test-rmse:94398
# [14]	train-rmse:92996.6	test-rmse:93433.5
# [15]	train-rmse:92210.3	test-rmse:92651.8
# [16]	train-rmse:91545.2	test-rmse:91992
# [17]	train-rmse:90999	test-rmse:91449.2
# [18]	train-rmse:90548.4	test-rmse:91007.5
# [19]	train-rmse:90176.4	test-rmse:90640.1
# [20]	train-rmse:89875.1	test-rmse:90341.6
# [21]	train-rmse:89622.4	test-rmse:90096
# [22]	train-rmse:89412.2	test-rmse:89893.5
# [23]	train-rmse:89238.1	test-rmse:89723.1
# [24]	train-rmse:89088.8	test-rmse:89579.4
# [25]	train-rmse:88967.9	test-rmse:89463.5
# [26]	train-rmse:88865.7	test-rmse:89368
# [27]	train-rmse:88779	test-rmse:89286.5
# [28]	train-rmse:88702.9	test-rmse:89214.5
# [29]	train-rmse:88641.3	test-rmse:89156.9
# [30]	train-rmse:88584.6	test-rmse:89107
# [31]	train-rmse:88538.2	test-rmse:89066.8
# [32]	train-rmse:88496	test-rmse:89032.9
# [33]	train-rmse:88461.2	test-rmse:89004.4
# [34]	train-rmse:88430.2	test-rmse:88982
# [35]	train-rmse:88402	test-rmse:88960.2
# [36]	train-rmse:88374.1	test-rmse:88935.9
# [37]	train-rmse:88351.1	test-rmse:88921.6
# [38]	train-rmse:88325.4	test-rmse:88902.1
# [39]	train-rmse:88307.1	test-rmse:88891.2
# [40]	train-rmse:88289.6	test-rmse:88879.9
# [41]	train-rmse:88274.3	test-rmse:88871.3
# [42]	train-rmse:88259.7	test-rmse:88862.6
# [43]	train-rmse:88245.3	test-rmse:88855
# [44]	train-rmse:88231.8	test-rmse:88847.7
# [45]	train-rmse:88214.6	test-rmse:88836.6
# [46]	train-rmse:88201.9	test-rmse:88831.4
# [47]	train-rmse:88186	test-rmse:88825.4
# [48]	train-rmse:88173.6	test-rmse:88818.7
# [49]	train-rmse:88160.7	test-rmse:88813.3
# [50]	train-rmse:88149.8	test-rmse:88810.9
# [51]	train-rmse:88136.6	test-rmse:88803.5
# [52]	train-rmse:88126	test-rmse:88800.8
# [53]	train-rmse:88116.1	test-rmse:88796.6
# [54]	train-rmse:88106.5	test-rmse:88794.9
# [55]	train-rmse:88093.7	test-rmse:88790.4
# [56]	train-rmse:88083.8	test-rmse:88787.2
# [57]	train-rmse:88073.2	test-rmse:88784.8
# [58]	train-rmse:88063.4	test-rmse:88782.1
# [59]	train-rmse:88051.2	test-rmse:88778.2
# [60]	train-rmse:88041.2	test-rmse:88775.8
# [61]	train-rmse:88033	test-rmse:88775
# [62]	train-rmse:88020.7	test-rmse:88771.5
# [63]	train-rmse:88010.6	test-rmse:88767.2
# [64]	train-rmse:88000.5	test-rmse:88766.7
# [65]	train-rmse:87992.2	test-rmse:88766.4
# [66]	train-rmse:87987.8	test-rmse:88764.5
# [67]	train-rmse:87980.3	test-rmse:88763.4
# [68]	train-rmse:87969.9	test-rmse:88761.3
# [69]	train-rmse:87960.7	test-rmse:88758.9
# [70]	train-rmse:87952.3	test-rmse:88756.6
# [71]	train-rmse:87938.4	test-rmse:88750.4
# [72]	train-rmse:87931.5	test-rmse:88750.3
# [73]	train-rmse:87925.7	test-rmse:88748.8
# [74]	train-rmse:87915.5	test-rmse:88744.7
# [75]	train-rmse:87908.3	test-rmse:88744
# [76]	train-rmse:87901.1	test-rmse:88743.1
# [77]	train-rmse:87894.3	test-rmse:88741.3
# [78]	train-rmse:87886.6	test-rmse:88741.5
# [79]	train-rmse:87880.7	test-rmse:88740.2
# [80]	train-rmse:87875.2	test-rmse:88740.4
# [81]	train-rmse:87866	test-rmse:88739.8
# [82]	train-rmse:87859.1	test-rmse:88740.2
# [83]	train-rmse:87855.2	test-rmse:88740.4
# [84]	train-rmse:87848	test-rmse:88739.5
# [85]	train-rmse:87840.7	test-rmse:88739.2
# [86]	train-rmse:87834.9	test-rmse:88738.6
# [87]	train-rmse:87828.4	test-rmse:88738
# [88]	train-rmse:87822.9	test-rmse:88738.5
# [89]	train-rmse:87815	test-rmse:88737
# [90]	train-rmse:87810.8	test-rmse:88736.6
# [91]	train-rmse:87808.6	test-rmse:88735.8
# [92]	train-rmse:87800.3	test-rmse:88735.1
# [93]	train-rmse:87789.9	test-rmse:88734.7
# [94]	train-rmse:87785.8	test-rmse:88733.4
# [95]	train-rmse:87780.7	test-rmse:88733.4
# [96]	train-rmse:87775	test-rmse:88733.7
# [97]	train-rmse:87771	test-rmse:88733.6
# [98]	train-rmse:87763.1	test-rmse:88734.2
# [99]	train-rmse:87755.9	test-rmse:88731.1
# [100]	train-rmse:87751	test-rmse:88730.7
# [101]	train-rmse:87744.4	test-rmse:88729.8
# [102]	train-rmse:87739.8	test-rmse:88730.3
# [103]	train-rmse:87737.7	test-rmse:88729.9
# [104]	train-rmse:87730	test-rmse:88729
# [105]	train-rmse:87726.3	test-rmse:88728.8
# [106]	train-rmse:87722.8	test-rmse:88728.3
# [107]	train-rmse:87713.4	test-rmse:88725.8
# [108]	train-rmse:87703.1	test-rmse:88723
# [109]	train-rmse:87693.1	test-rmse:88719.9
# [110]	train-rmse:87685.3	test-rmse:88718.9
# [111]	train-rmse:87676.9	test-rmse:88717.6
# [112]	train-rmse:87672.1	test-rmse:88717.8
# [113]	train-rmse:87667.2	test-rmse:88719.1
# [114]	train-rmse:87664.5	test-rmse:88718.9
# [115]	train-rmse:87659.2	test-rmse:88718.4
# [116]	train-rmse:87653	test-rmse:88718.4
# [117]	train-rmse:87651.7	test-rmse:88717.9
# [118]	train-rmse:87645.4	test-rmse:88717.4
# [119]	train-rmse:87639.2	test-rmse:88717.2
# [120]	train-rmse:87631.8	test-rmse:88716.7
# [121]	train-rmse:87627	test-rmse:88716
# [122]	train-rmse:87622.2	test-rmse:88716.3
# [123]	train-rmse:87617.5	test-rmse:88715.2
# [124]	train-rmse:87613.5	test-rmse:88715.9
# [125]	train-rmse:87605.3	test-rmse:88715.6
# [126]	train-rmse:87599.2	test-rmse:88714.6
# [127]	train-rmse:87592.4	test-rmse:88713.7
# [128]	train-rmse:87585.4	test-rmse:88713.6
# [129]	train-rmse:87581.2	test-rmse:88713.4
# [130]	train-rmse:87576.1	test-rmse:88712.9
# [131]	train-rmse:87568.4	test-rmse:88713.1
# [132]	train-rmse:87560.4	test-rmse:88710.9
# [133]	train-rmse:87556.8	test-rmse:88710.7
# [134]	train-rmse:87551.2	test-rmse:88710.3
# [135]	train-rmse:87547.4	test-rmse:88711.8
# [136]	train-rmse:87543.3	test-rmse:88712
# [137]	train-rmse:87535.6	test-rmse:88711.8
# [138]	train-rmse:87531.6	test-rmse:88711.8
# [139]	train-rmse:87530.7	test-rmse:88712.1
# [140]	train-rmse:87525.9	test-rmse:88712
# [141]	train-rmse:87520.7	test-rmse:88712.2
# [142]	train-rmse:87515.2	test-rmse:88712.5
# [143]	train-rmse:87514.4	test-rmse:88712.5
# [144]	train-rmse:87510.1	test-rmse:88712.8
# [145]	train-rmse:87506.4	test-rmse:88713.6
# [146]	train-rmse:87500.8	test-rmse:88713.2
# [147]	train-rmse:87497.3	test-rmse:88712.5
# [148]	train-rmse:87489.7	test-rmse:88712.7
# [149]	train-rmse:87483.1	test-rmse:88711.1
# [150]	train-rmse:87479.6	test-rmse:88711.6
# [151]	train-rmse:87476.3	test-rmse:88712.1
# [152]	train-rmse:87472.7	test-rmse:88711.4
# [153]	train-rmse:87467.9	test-rmse:88710.2
# [154]	train-rmse:87464	test-rmse:88709.9
# [155]	train-rmse:87457.6	test-rmse:88710.2
# [156]	train-rmse:87449.6	test-rmse:88710
# [157]	train-rmse:87445.7	test-rmse:88709
# [158]	train-rmse:87440	test-rmse:88708.3
# [159]	train-rmse:87434.3	test-rmse:88707
# [160]	train-rmse:87429.2	test-rmse:88708
# [161]	train-rmse:87421.9	test-rmse:88708.2
# [162]	train-rmse:87414.3	test-rmse:88707.6
# [163]	train-rmse:87411.1	test-rmse:88707.5
# [164]	train-rmse:87405.6	test-rmse:88707.1
# [165]	train-rmse:87403.2	test-rmse:88707
# [166]	train-rmse:87395.3	test-rmse:88707.5
# [167]	train-rmse:87394.2	test-rmse:88707.4
# [168]	train-rmse:87391.5	test-rmse:88708.2
# [169]	train-rmse:87382.8	test-rmse:88706.8
# [170]	train-rmse:87376.7	test-rmse:88707.1
# [171]	train-rmse:87373.9	test-rmse:88707.9
# [172]	train-rmse:87368.7	test-rmse:88707.4
# [173]	train-rmse:87362.8	test-rmse:88707
# [174]	train-rmse:87358.9	test-rmse:88706.9
# [175]	train-rmse:87354.3	test-rmse:88707
# [176]	train-rmse:87350.6	test-rmse:88707.4
# [177]	train-rmse:87348.1	test-rmse:88707.3
# [178]	train-rmse:87344.3	test-rmse:88707.1
# [179]	train-rmse:87340.8	test-rmse:88707.4
# [180]	train-rmse:87333.4	test-rmse:88706.2
# [181]	train-rmse:87328.4	test-rmse:88706.9
# [182]	train-rmse:87326.9	test-rmse:88706.6
# [183]	train-rmse:87323.6	test-rmse:88705.9
# [184]	train-rmse:87321.6	test-rmse:88706
# [185]	train-rmse:87320.9	test-rmse:88706
# [186]	train-rmse:87312.7	test-rmse:88707.9
# [187]	train-rmse:87304.5	test-rmse:88707.7
# [188]	train-rmse:87297.6	test-rmse:88706.4
# [189]	train-rmse:87290.6	test-rmse:88706.2
# [190]	train-rmse:87284.8	test-rmse:88706.2
# [191]	train-rmse:87279.5	test-rmse:88706.9
# [192]	train-rmse:87273.4	test-rmse:88707.7
# [193]	train-rmse:87268.8	test-rmse:88708.3
# [194]	train-rmse:87262.9	test-rmse:88708.4
# [195]	train-rmse:87257.9	test-rmse:88707.6
# [196]	train-rmse:87253.1	test-rmse:88707.6
# [197]	train-rmse:87250.9	test-rmse:88708.4
# [198]	train-rmse:87248.2	test-rmse:88708.6
# [199]	train-rmse:87240.8	test-rmse:88708.6
# [200]	train-rmse:87237.3	test-rmse:88709.4
# [201]	train-rmse:87234.1	test-rmse:88709.3
# [202]	train-rmse:87229.8	test-rmse:88709.1
# [203]	train-rmse:87226.4	test-rmse:88709.2
# [204]	train-rmse:87221	test-rmse:88709
# [205]	train-rmse:87217.6	test-rmse:88709.7
# [206]	train-rmse:87213.3	test-rmse:88709
# [207]	train-rmse:87211.2	test-rmse:88709.1
# [208]	train-rmse:87206.6	test-rmse:88709.1
# [209]	train-rmse:87199.5	test-rmse:88708.1
# [210]	train-rmse:87195.4	test-rmse:88708.4
# [211]	train-rmse:87194.8	test-rmse:88708.7
# [212]	train-rmse:87192.5	test-rmse:88709.6
# [213]	train-rmse:87187.1	test-rmse:88709.2
# [214]	train-rmse:87186.5	test-rmse:88709.1
# [215]	train-rmse:87179.3	test-rmse:88708.5
# [216]	train-rmse:87174.2	test-rmse:88709.4
# [217]	train-rmse:87168.9	test-rmse:88709.6
# [218]	train-rmse:87164.4	test-rmse:88710.2
# [219]	train-rmse:87159.1	test-rmse:88710.9
# [220]	train-rmse:87155.7	test-rmse:88711.4
# [221]	train-rmse:87153.9	test-rmse:88711.3
# [222]	train-rmse:87148.9	test-rmse:88711.8
# [223]	train-rmse:87142.6	test-rmse:88711.2
# Stopping. Best iteration:
# [183]	train-rmse:87323.6	test-rmse:88705.9
